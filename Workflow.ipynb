# %% [markdown]
# # Reproducible Workflow
# This notebook is intended to be a walkthrough of the paper results with examples that convey the main idea. We show the workflow for the entire paper.
# * To load the LUBM Graph we use a public endpoint on [Dydra](http://dydra.com).
# However for larger test cases we run our tests on Apache Jena. In case you have a LUBM on your local/public endpoint, you can load it as well. Please note that the LUBM that we use is _materialized_. The inferencing is **RDFS**.
#
# * The DBpedia endpoint is a local endpoint, and if you want to test it, please replace it with either the public endpoint or your own local endpoint
#
# * For any other questions or suggestions or concerns with the procedures, please do contact me kannaa@rpi.edu, I'll be glad to include your suggestions.

# %% [markdown]
# # Relaxation
# Relaxation is the standard baseline for reformulating SPARQL queries. A lot of related work exists on reformulating SPARQL queries. The ideas are inherently based on *flexible* querying. In this notion, the different conditions in the input query are *loosened* or *relaxed* to give more results. This can also be looked at as *exploratory* querying.
#
# ## SPARQL Query Relaxation
# Lets have a look at this hierarchy from LUBM on all teaching faculty in a University.
# * Employee
# * * Faculty
# * * * Professor
# * * * * VisitingProfessor
# * * * * FullProfessor
# * * * * Dean
# * * * * Chair
# * * * * AssociateProfessor
# * * * * AssistantProfessor
# * * * * PostDoc
# * * * * Lecturer
#
# Lets look how relaxation helps in getting more answers. In this case consider the following query on LUBM
#
#
# ```Select ?teacher where {
#     ?teacher a Lecturer .
# } ```
#
# Lets see the results that we get from LUBM

# %%
from rdflib import Graph
g = Graph()
g.parse('lubm_saturated.nt',format="nt")
print("Total triple statements in LUBM is " + str(len(g)))
# Out:
# Total triple statements in LUBM is 144299

# %%
from SPARQLWrapper import SPARQLWrapper, JSON
from IPython.display import display
import pandas as pd
import json
import numpy as np
from pandas.io.json import json_normalize

pd.options.display.max_colwidth = 100
pd.options.display.max_rows = 999

#Procedure to execute a SPARQL Query and get a pandas object out of it
def execute_query(sparqlQuery,endpoint):
    sparql = SPARQLWrapper(endpoint)
    sparql.setQuery(sparqlQuery)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    results_df = json_normalize(results["results"]["bindings"])
    return results_df

# %%
# %%time
query  = """

PREFIX  ub: <http://swat.cse.lehigh.edu/onto/univ-bench.owl#>
Select ?teacher where {
    # ?teacher a ub:Lecturer .
}

"""
endpoint  = "https://dydra.com/amarviswanathan/lubm/sparql"
results_df = execute_query(query,endpoint)

#Show the top-5 results
results_df.head()
# Out:
# CPU times: user 8 ms, sys: 0 ns, total: 8 ms
# Wall time: 540 ms

# %%
#Total number of lecturers
shape = results_df.shape
print("There are " + str(shape[0]) + " lecturers")
# Out:
# There are 93 lecturers

# %% [markdown]
# But if the user is not satisfied with these 93 lecturers and wants to find more of them, a simple way is to relax by moving up in the hierarchy. So we move from Lecturer to Professor. This gives us the following query :
#
# ```
# Select ?teacher where {
#     ?teacher a ub:Professor .
# }
# ```

# %%
# %%time 
relaxed_query  = """

PREFIX  ub: <http://swat.cse.lehigh.edu/onto/univ-bench.owl#>
Select ?teacher where {
    # ?teacher a ub:Professor .
}
"""
results_df = execute_query(relaxed_query,endpoint)

#Show the top-5 results
results_df.head()
# Out:
# CPU times: user 12 ms, sys: 4 ms, total: 16 ms
# Wall time: 703 ms

# %%
#Total number of lecturers
shape = results_df.shape
print("There are " + str(shape[0]) + " Professors")
# Out:
# There are 447 Professors

# %% [markdown]
# The above result gives us 447 Professors, each of whom may be any type under the hierarchy of **Professor**.

# %% [markdown]
# ## Instance Query
# Let us look at an instance of a **Professor** i.e. **<http://www.Department14.University0.edu/FullProfessor4>** and see what courses this Professor teaches.

# %%
# %%time 
entity_query = """
PREFIX  ub: <http://swat.cse.lehigh.edu/onto/univ-bench.owl#>
Select ?course where {
   <http://www.Department14.University0.edu/FullProfessor4> ub:teacherOf  ?course .
}
"""

results_df = execute_query(entity_query,endpoint)
results_df = results_df[['course.value']]
# Show all the results
results_df
# Out:
# CPU times: user 4 ms, sys: 4 ms, total: 8 ms
# Wall time: 482 ms

# %% [markdown]
# So the **FullProfessor4** teaches `2 Graduate Courses` and `1 Course`.  **If** the user decides to want more answers, an automatic way would be to relax the query. Thus the system wouldrelax this entity value. However the entity has **no hierarchy**. Which means this entity ends up being relaxed to a variable. This is known as `simple relaxation`. The relaxed query then becomes
#
#
# ```Select ?course where {
#     ?teacher ub:teacherOf ?course .
# } ```

# %%
# %%time 
entity_relaxed_query = """
PREFIX  ub: <http://swat.cse.lehigh.edu/onto/univ-bench.owl#>
Select ?teacher ?course where {
   # ?teacher ub:teacherOf  ?course .
}
"""

relax_df = execute_query(entity_relaxed_query,endpoint)

# Show all the results
relax_df
print("The total courses are " + str(relax_df.shape[0]))

relax_df.head()
# Out:
# The total courses are 1627
# CPU times: user 64 ms, sys: 4 ms, total: 68 ms
# Wall time: 1.31 s

# %% [markdown]
# # Motivation
# In this case, we end up relaxing the query to find _Anybody who takes any course_. Now this ends up giving `1627 results` and is very _generalized_. While this is logically right, wouldn't it be more beneficial if the system resulted in courses are more similar to what **Professor14** teaches?

# %% [markdown]
# # Goal
#
# To address this issue, we present a technique where we utilize the _entity_ statements present in the graph to suggest reformulations. Let us see how this makes sense. Entities have properties(_predicate_) and values (_object_) in the graph. For example the entity **Professor14** has this triple associated with it
#
# | Subject        | Predicate           | Object  |
# | ------------- |:-------------:| -----:|
# |**Professor14**|teacherOf|GraduateCourse5|
#
#
# One could easily utilize these values much more effectively to create _triple patterns_ that can be appended back to the original query. This can then be used to suggest reformulations. We call the **predicate** and **object** value pair as a _feature_ or a _fact_. This is because they provide more contextual information about the entity in the RDF or RDFS graph. Since we utilize these features(facts) to create reformulations, we call our method
# **Feature based reformulation of entities in triple pattern queries**.
#
# The features provide more _information_ and _context_ about an entity. Let us see how features can be used. To do that we print out the features of **FullProfessor4** from LUBM.

# %%
entity_statement_query = """
PREFIX  ub: <http://swat.cse.lehigh.edu/onto/univ-bench.owl#>
Select ?p ?o where {
   <http://www.Department14.University0.edu/FullProfessor4> ?p ?o .
}
"""

results_df = execute_query(entity_statement_query,endpoint)

# Show all the results
results_df
# Out:
#                                  o.datatype   o.type  \
# 0                                       NaN      uri
# 1                                       NaN      uri
# 2                                       NaN      uri
# 3                                       NaN      uri
# 4                                       NaN      uri
# 5                                       NaN      uri
# 6   http://www.w3.org/2001/XMLSchema#string  literal
# 7                                       NaN      uri
# 8                                       NaN      uri
# 9                                       NaN      uri
# 10                                      NaN      uri
# 11                                      NaN      uri
# 12                                      NaN      uri
# 13                                      NaN      uri
# 14  http://www.w3.org/2001/XMLSchema#string  literal
# 15  http://www.w3.org/2001/XMLSchema#string  literal
# 16  http://www.w3.org/2001/XMLSchema#string  literal
# 17                                      NaN      uri
# 18                                      NaN      uri
# 19                                      NaN      uri
# 20                                      NaN      uri
#
#                                                          o.value p.type  \
# 0                  http://www.w3.org/2000/01/rdf-schema#Resource    uri
# 1   http://swat.cse.lehigh.edu/onto/univ-bench.owl#FullProfessor    uri
# 2         http://swat.cse.lehigh.edu/onto/univ-bench.owl#Faculty    uri
# 3          http://swat.cse.lehigh.edu/onto/univ-bench.owl#Person    uri
# 4       http://swat.cse.lehigh.edu/onto/univ-bench.owl#Professor    uri
# 5        http://swat.cse.lehigh.edu/onto/univ-bench.owl#Employee    uri
# 6                                                 FullProfessor4    uri
# 7        http://www.Department14.University0.edu/GraduateCourse5    uri
# 8                http://www.Department14.University0.edu/Course4    uri
# 9        http://www.Department14.University0.edu/GraduateCourse4    uri
# 10                                  http://www.University214.edu    uri
# 11                                  http://www.University912.edu    uri
# 12                                  http://www.University801.edu    uri
# 13                       http://www.Department14.University0.edu    uri
# 14                   FullProfessor4@Department14.University0.edu    uri
# 15                                                  xxx-xxx-xxxx    uri
# 16                                                    Research25    uri
# 17                       http://www.Department14.University0.edu    uri
# 18                                  http://www.University214.edu    uri
# 19                                  http://www.University912.edu    uri
# 20                                  http://www.University801.edu    uri
#
#                                                                    p.value
# 0                          http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 1                          http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 2                          http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 3                          http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 4                          http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 5                          http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 6                      http://swat.cse.lehigh.edu/onto/univ-bench.owl#name
# 7                 http://swat.cse.lehigh.edu/onto/univ-bench.owl#teacherOf
# 8                 http://swat.cse.lehigh.edu/onto/univ-bench.owl#teacherOf
# 9                 http://swat.cse.lehigh.edu/onto/univ-bench.owl#teacherOf
# 10  http://swat.cse.lehigh.edu/onto/univ-bench.owl#undergraduateDegreeFrom
# 11        http://swat.cse.lehigh.edu/onto/univ-bench.owl#mastersDegreeFrom
# 12       http://swat.cse.lehigh.edu/onto/univ-bench.owl#doctoralDegreeFrom
# 13                 http://swat.cse.lehigh.edu/onto/univ-bench.owl#worksFor
# 14             http://swat.cse.lehigh.edu/onto/univ-bench.owl#emailAddress
# 15                http://swat.cse.lehigh.edu/onto/univ-bench.owl#telephone
# 16         http://swat.cse.lehigh.edu/onto/univ-bench.owl#researchInterest
# 17                 http://swat.cse.lehigh.edu/onto/univ-bench.owl#memberOf
# 18               http://swat.cse.lehigh.edu/onto/univ-bench.owl#degreeFrom
# 19               http://swat.cse.lehigh.edu/onto/univ-bench.owl#degreeFrom
# 20               http://swat.cse.lehigh.edu/onto/univ-bench.owl#degreeFrom

# %% [markdown]
# From the above result we see that the `literal` values don't add more information to the triple except that they are string values for an entity. Morever, they don't have any statements associated with them. So we filter the literal values out first.

# %%
results_df = results_df[results_df['o.type'] == 'uri']
results_df = results_df[['p.value','o.value']]
results_df
# Out:
#                                                                    p.value  \
# 0                          http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 1                          http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 2                          http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 3                          http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 4                          http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 5                          http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 7                 http://swat.cse.lehigh.edu/onto/univ-bench.owl#teacherOf
# 8                 http://swat.cse.lehigh.edu/onto/univ-bench.owl#teacherOf
# 9                 http://swat.cse.lehigh.edu/onto/univ-bench.owl#teacherOf
# 10  http://swat.cse.lehigh.edu/onto/univ-bench.owl#undergraduateDegreeFrom
# 11        http://swat.cse.lehigh.edu/onto/univ-bench.owl#mastersDegreeFrom
# 12       http://swat.cse.lehigh.edu/onto/univ-bench.owl#doctoralDegreeFrom
# 13                 http://swat.cse.lehigh.edu/onto/univ-bench.owl#worksFor
# 17                 http://swat.cse.lehigh.edu/onto/univ-bench.owl#memberOf
# 18               http://swat.cse.lehigh.edu/onto/univ-bench.owl#degreeFrom
# 19               http://swat.cse.lehigh.edu/onto/univ-bench.owl#degreeFrom
# 20               http://swat.cse.lehigh.edu/onto/univ-bench.owl#degreeFrom
#
#                                                          o.value
# 0                  http://www.w3.org/2000/01/rdf-schema#Resource
# 1   http://swat.cse.lehigh.edu/onto/univ-bench.owl#FullProfessor
# 2         http://swat.cse.lehigh.edu/onto/univ-bench.owl#Faculty
# 3          http://swat.cse.lehigh.edu/onto/univ-bench.owl#Person
# 4       http://swat.cse.lehigh.edu/onto/univ-bench.owl#Professor
# 5        http://swat.cse.lehigh.edu/onto/univ-bench.owl#Employee
# 7        http://www.Department14.University0.edu/GraduateCourse5
# 8                http://www.Department14.University0.edu/Course4
# 9        http://www.Department14.University0.edu/GraduateCourse4
# 10                                  http://www.University214.edu
# 11                                  http://www.University912.edu
# 12                                  http://www.University801.edu
# 13                       http://www.Department14.University0.edu
# 17                       http://www.Department14.University0.edu
# 18                                  http://www.University214.edu
# 19                                  http://www.University912.edu
# 20                                  http://www.University801.edu

# %% [markdown]
# The element in `row 0`, is too generic because it tags anything as a resource. So instead of that lets eyeball some interesting properties and change our initial query. For the sake of this example I pick
#
# | Predicate        | Object           |
# | ------------- |:-------------:|
# |**mastersDegreeFrom**|University912.edu|
# |**memberOf**|Department14.University0.edu|
#
# The above two properties say something about the entity **Professor14** i.e. it says that **Professor14** got his `doctoralDegreeFrom University801.edu` and is `memberOf Department14.University0.edu`. To utilize these features in a query, one just has to convert them to a pattern so that it becomes a valid _triple pattern_. This is shown in the table below :

# %% [markdown]
# ### Entity Statements
#
#
# |Entity| Predicate | Value|
# |--|--|--|
# |**Professor14**| **mastersDegreeFrom**|University912.edu|
# |**Professor14**| **memberOf**|Department14.University0.edu|
#
# Replacing the entity **Professor14** with a variable `?x` we get the following :
# ### Entity Feature Patterns
#
# |Variable|Predicate|Value|
# |--|--|--|
# |?x|**mastersDegreeFrom**|University912.edu|
# |?x|**memberOf**|Department14.University0.edu|

# %% [markdown]
# Now let us pick the first pattern and add it back to the original query. Then lets add the second pattern to the original query independently.  This results in a  reformulated queries that looks like :
#
# ```
# Select ?course where {
#    ?x ub:teacherOf  ?course .
#    ?x mastersDegreeFrom University912.edu .
# }
# ```
#
# ```
# Select ?course where {
#    ?x ub:teacherOf  ?course .
#    ?x memberOf Department14.University0.edu .
# }
# ```

# %% [markdown]
# The inital query was :
#
# * Select courses taught by **FullProfessor4**
#
# Adding the two new features the query becomes :
# * Select courses taught by ?x who has a mastersDegreeFrom `University912.edu`
# * Select courses taught by ?x who is a member of `Department14.Univeristy0.edu` .
#
# Both the above queries are more contextual and give precise answers than the initial relaxation which read as
# * Select all courses taught by any teacher
#
# So lets run the reformulation to see the results.

# %%
# %%time 
entity_reformulated_query = """
PREFIX  ub: <http://swat.cse.lehigh.edu/onto/univ-bench.owl#>
Select ?course where {
   # ?x ub:teacherOf ?course .
   # ?x ub:mastersDegreeFrom <http://www.University912.edu> .
   
}
"""

ref_1 = execute_query(entity_reformulated_query,endpoint)

# Show all the results
print("The number of courses now is " + str(ref_1.shape[0]))
ref_1.head()
# Out:
# The number of courses now is 5
# CPU times: user 4 ms, sys: 4 ms, total: 8 ms
# Wall time: 457 ms

# %%
# %%time 
entity_reformulated_query = """
PREFIX  ub: <http://swat.cse.lehigh.edu/onto/univ-bench.owl#>
Select ?course where {
   # ?x ub:teacherOf ?course .
   # ?x ub:memberOf <http://www.Department14.University0.edu> .
   
}
"""

ref_2 = execute_query(entity_reformulated_query,endpoint)

# Show all the results
print("The number of courses now is " + str(ref_2.shape[0]))
ref_2.head()
# Out:
# The number of courses now is 97
# CPU times: user 8 ms, sys: 0 ns, total: 8 ms
# Wall time: 591 ms

# %% [markdown]
# Now lets find the common results between the two reformulations

# %%
overall_ref = pd.merge(ref_1,ref_2,how='inner',on=['course.type','course.value'])
overall_ref
# Out:
#   course.type                                             course.value
# 0         uri  http://www.Department14.University0.edu/GraduateCourse5
# 1         uri          http://www.Department14.University0.edu/Course4
# 2         uri  http://www.Department14.University0.edu/GraduateCourse4

# %% [markdown]
# Lets find the results that are not common between the two reformulations.

# %%
merged_df = pd.concat([ref_1,ref_2])
merged_df  = merged_df.drop_duplicates(keep=False)
merged_df.shape[0]
# Out:
# 96

# %% [markdown]
# So we now have the following comparisons between relaxation and reformulation. There are a total of `96 + 3 = 99 ` unique results out of the reformulation procedure, whereas the relaxation has a total of `1627` results. The `99` results are more related to the `?course` variable of the original query because of using the features.
#
# ### Results Comparison
# | Original Query        | **Relaxation**           | Ref-1 | Ref-2 | Combined |
# | ------------- |:-------------:|:--------:|:-------:|:---------|
# |3|1627|5|97|99|
#
# ### Time Comparison
#  | **Relaxation**           | Ref-1 | Ref-2 |
# |:-------------:|:--------:|:-------:|
# |1310ms|457ms|591ms|
#
# * Clearly the **relaxation results are higher, whereas the reformulation results are lesser**. This makes this kind of reformulation more precise.
# * In addition the time calculation shows that the **resulting reformulations also run in lesser time than the relaxed version of the query**.
#
# This can be visualized as
#
# ![results](files/images/Chart.png)
#
#
# You can access this visualization at the [jsfiddle](http://jsfiddle.net/N00bsie/hk6vjz4o/)

# %% [markdown]
# ## Selecting Interesting Features
#
# In the previous sections, we focused on the aspect of showing that an entity reformulation is more **contextual** and **precise** than an _entity relaxation_. However the following question remains :
# * **Why do you need to pick subsets of features from the graph?**
# * **How do you select relevant _features_ for an entity?**
# * **Entities in large graphs have a lot of features. How many do you select?**
#
# ## DBpedia Example
#
# Let us take an entity query involving `dbr:Martin_Scorsese`.  Assuming that initially the user is interested in looking at movies made by people similar to `dbr:Martin_Scorsese` and he starts out by making a query about the _movies made by_ `dbr:Martin_Scorsese`. Lets run it on the DBpedia end point to see what answers we get.

# %%
dbpedia_query ="""
PREFIX  schema: <http://schema.org/>
PREFIX  dbr:  <http://dbpedia.org/resource/>
PREFIX  umbel-rc: <http://umbel.org/umbel/rc/>
PREFIX  dbc:  <http://dbpedia.org/resource/Category:>
PREFIX  owl:  <http://www.w3.org/2002/07/owl#>
PREFIX  yago: <http://dbpedia.org/class/yago/>
PREFIX  rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX  dbo:  <http://dbpedia.org/ontology/>
PREFIX  dbp:  <http://dbpedia.org/property/>
PREFIX  rdf:  <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX  dcterms: <http://purl.org/dc/terms/>
PREFIX  dbpedia-wikidata: <http://wikidata.dbpedia.org/resource/>
PREFIX  dul:  <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
PREFIX  foaf: <http://xmlns.com/foaf/0.1/>
PREFIX  dc:   <http://purl.org/dc/elements/1.1/>
PREFIX prov: <http://www.w3.org/ns/prov#>

SELECT  Distinct ?movie 
WHERE
  { 
    
     # ?movie dbo:director dbr:Martin_Scorsese .
  }

"""
dbpedia_endpoint = "http://zen.cs.rpi.edu:8890/sparql"
movies_df = execute_query(dbpedia_query,dbpedia_endpoint)
print("The movies directed by dbr:Martin_Scorsese are :")
movies_df
# Out:
# The movies directed by dbr:Martin_Scorsese are :
#    movie.type  \
# 0         uri
# 1         uri
# 2         uri
# 3         uri
# 4         uri
# 5         uri
# 6         uri
# 7         uri
# 8         uri
# 9         uri
# 10        uri
# 11        uri
# 12        uri
# 13        uri
# 14        uri
# 15        uri
# 16        uri
# 17        uri
# 18        uri
# 19        uri
# 20        uri
# 21        uri
# 22        uri
# 23        uri
# 24        uri
# 25        uri
# 26        uri
# 27        uri
# 28        uri
# 29        uri
# 30        uri
# 31        uri
# 32        uri
# 33        uri
# 34        uri
# 35        uri
# 36        uri
# 37        uri
# 38        uri
# 39        uri
# 40        uri
# 41        uri
# 42        uri
# 43        uri
# 44        uri
#
#                                                                                     movie.value
# 0                                                     http://dbpedia.org/resource/Made_in_Milan
# 1                                                http://dbpedia.org/resource/The_Key_to_Reserva
# 2                                                      http://dbpedia.org/resource/Mean_Streets
# 3                                                       http://dbpedia.org/resource/Raging_Bull
# 4                                                       http://dbpedia.org/resource/Taxi_Driver
# 5                                   http://dbpedia.org/resource/Alice_Doesn't_Live_Here_Anymore
# 6                                    http://dbpedia.org/resource/The_King_of_Comedy_(1983_film)
# 7                                                     http://dbpedia.org/resource/Boxcar_Bertha
# 8                                    http://dbpedia.org/resource/Who's_That_Knocking_at_My_Door
# 9                                                http://dbpedia.org/resource/My_Voyage_to_Italy
# 10                                                       http://dbpedia.org/resource/Goodfellas
# 11                                               http://dbpedia.org/resource/After_Hours_(film)
# 12                                                 http://dbpedia.org/resource/New_York_Stories
# 13                                                           http://dbpedia.org/resource/Kundun
# 14                                                http://dbpedia.org/resource/No_Direction_Home
# 15                                                    http://dbpedia.org/resource/Street_Scenes
# 16                                                 http://dbpedia.org/resource/The_Blues_(film)
# 17                             http://dbpedia.org/resource/The_Last_Temptation_of_Christ_(film)
# 18                                                http://dbpedia.org/resource/Vinyl_(TV_series)
# 19                                            http://dbpedia.org/resource/Bringing_Out_the_Dead
# 20                                          http://dbpedia.org/resource/The_Aviator_(2004_film)
# 21                                            http://dbpedia.org/resource/Shutter_Island_(film)
# 22                                              http://dbpedia.org/resource/Silence_(2016_film)
# 23                                                    http://dbpedia.org/resource/Casino_(film)
# 24                                        http://dbpedia.org/resource/New_York,_New_York_(film)
# 25                                                     http://dbpedia.org/resource/The_Departed
# 26  http://dbpedia.org/resource/A_Personal_Journey_with_Martin_Scorsese_Through_American_Movies
# 27                                 http://dbpedia.org/resource/The_Age_of_Innocence_(1993_film)
# 28        http://dbpedia.org/resource/What's_a_Nice_Girl_Like_You_Doing_in_a_Place_Like_This%3F
# 29                                             http://dbpedia.org/resource/Shine_a_Light_(film)
# 30                         http://dbpedia.org/resource/Shine_a_Light_(The_Rolling_Stones_album)
# 31                    http://dbpedia.org/resource/George_Harrison:_Living_in_the_Material_World
# 32                                                 http://dbpedia.org/resource/A_Letter_to_Elia
# 33                                            http://dbpedia.org/resource/Cape_Fear_(1991_film)
# 34                                                http://dbpedia.org/resource/Gangs_of_New_York
# 35                                               http://dbpedia.org/resource/The_Color_of_Money
# 36                                                   http://dbpedia.org/resource/The_Last_Waltz
# 37                                                    http://dbpedia.org/resource/The_Big_Shave
# 38                                                  http://dbpedia.org/resource/Italianamerican
# 39                         http://dbpedia.org/resource/American_Boy:_A_Profile_of_Steven_Prince
# 40                                       http://dbpedia.org/resource/It's_Not_Just_You,_Murray!
# 41                                                      http://dbpedia.org/resource/Hugo_(film)
# 42                                       http://dbpedia.org/resource/Boardwalk_Empire_(episode)
# 43                              http://dbpedia.org/resource/The_Wolf_of_Wall_Street_(2013_film)
# 44                                           http://dbpedia.org/resource/Public_Speaking_(film)

# %%
print("dbr:Martin_Scorsese has directed a total of " + str(movies_df.shape[0]) + " movies")
# Out:
# dbr:Martin_Scorsese has directed a total of 45 movies

# %% [markdown]
# As before lets relaxing `dbr:Martin_Scorsese` will lead to to the following query
#
# ```
# SELECT  Distinct ?movie
# WHERE
#   {
#
#      ?movie dbo:director ?y .
#   }
# ```
# Let us execute this query on DBpedia to see how many movies we get

# %%
# %%time 
dbpedia_query ="""
PREFIX  schema: <http://schema.org/>
PREFIX  dbr:  <http://dbpedia.org/resource/>
PREFIX  umbel-rc: <http://umbel.org/umbel/rc/>
PREFIX  dbc:  <http://dbpedia.org/resource/Category:>
PREFIX  owl:  <http://www.w3.org/2002/07/owl#>
PREFIX  yago: <http://dbpedia.org/class/yago/>
PREFIX  rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX  dbo:  <http://dbpedia.org/ontology/>
PREFIX  dbp:  <http://dbpedia.org/property/>
PREFIX  rdf:  <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX  dcterms: <http://purl.org/dc/terms/>
PREFIX  dbpedia-wikidata: <http://wikidata.dbpedia.org/resource/>
PREFIX  dul:  <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
PREFIX  foaf: <http://xmlns.com/foaf/0.1/>
PREFIX  dc:   <http://purl.org/dc/elements/1.1/>
PREFIX prov: <http://www.w3.org/ns/prov#>

SELECT  Distinct ?movie 
WHERE
  { 
    
     # ?movie dbo:director ?y .
  }

"""
dbpedia_endpoint = "http://zen.cs.rpi.edu:8890/sparql"
movies_df = execute_query(dbpedia_query,dbpedia_endpoint)
print("The toal movies directed by anybody are : " + str(movies_df.shape[0]))
# Out:
# The toal movies directed by anybody are : 103317
# CPU times: user 2.44 s, sys: 60 ms, total: 2.5 s
# Wall time: 5.01 s

# %% [markdown]
# Looking at the results, you would realize that not all the results are movies. For example the entity `http://dbpedia.org/resource/Indianapolis_Art_Center
# n` at row index `102808` is not a movie, but rather an organization.

# %%
print(movies_df.loc[102808])
# Out:
# movie.type                                                     uri
# movie.value    http://dbpedia.org/resource/Indianapolis_Art_Center
# Name: 102808, dtype: object

# %% [markdown]
# This happens because the query is very generalized because of the _relaxation_. To address this we need to execute queries that are contextually similar to the original query.  Following what was discussed earlier, we start by looking at the properties of the entity `dbr:Martin_Scorsese`.

# %%
# %%time 
dbpedia_entity_feature_query ="""
PREFIX  schema: <http://schema.org/>
PREFIX  dbr:  <http://dbpedia.org/resource/>
PREFIX  umbel-rc: <http://umbel.org/umbel/rc/>
PREFIX  dbc:  <http://dbpedia.org/resource/Category:>
PREFIX  owl:  <http://www.w3.org/2002/07/owl#>
PREFIX  yago: <http://dbpedia.org/class/yago/>
PREFIX  rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX  dbo:  <http://dbpedia.org/ontology/>
PREFIX  dbp:  <http://dbpedia.org/property/>
PREFIX  rdf:  <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX  dcterms: <http://purl.org/dc/terms/>
PREFIX  dbpedia-wikidata: <http://wikidata.dbpedia.org/resource/>
PREFIX  dul:  <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
PREFIX  foaf: <http://xmlns.com/foaf/0.1/>
PREFIX  dc:   <http://purl.org/dc/elements/1.1/>
PREFIX prov: <http://www.w3.org/ns/prov#>

SELECT ?p ?o 
WHERE
  { 
    
     dbr:Martin_Scorsese ?p ?o .
  }
"""
dbpedia_endpoint = "http://zen.cs.rpi.edu:8890/sparql"
entity_features = execute_query(dbpedia_entity_feature_query,dbpedia_endpoint)
display(entity_features)
# Out:
#                                    o.datatype         o.type  \
# 0                                         NaN            uri
# 1                                         NaN            uri
# 2                                         NaN            uri
# 3                                         NaN            uri
# 4                                         NaN            uri
# 5                                         NaN            uri
# 6                                         NaN            uri
# 7                                         NaN            uri
# 8                                         NaN            uri
# 9                                         NaN        literal
# 10                                        NaN        literal
# 11                                        NaN        literal
# 12                                        NaN        literal
# 13                                        NaN        literal
# 14                                        NaN        literal
# 15                                        NaN        literal
# 16                                        NaN        literal
# 17                                        NaN        literal
# 18                                        NaN        literal
# 19                                        NaN        literal
# 20                                        NaN        literal
# 21                                        NaN        literal
# 22                                        NaN        literal
# 23                                        NaN        literal
# 24                                        NaN        literal
# 25                                        NaN        literal
# 26                                        NaN        literal
# 27                                        NaN        literal
# 28                                        NaN        literal
# 29                                        NaN        literal
# 30                                        NaN        literal
# 31                                        NaN        literal
# 32                                        NaN            uri
# 33                                        NaN            uri
# 34                                        NaN            uri
# 35                                        NaN            uri
# 36                                        NaN            uri
# 37                                        NaN            uri
# 38                                        NaN            uri
# 39                                        NaN            uri
# 40                                        NaN            uri
# 41                                        NaN            uri
# 42                                        NaN            uri
# 43                                        NaN            uri
# 44                                        NaN            uri
# 45                                        NaN            uri
# 46                                        NaN            uri
# 47                                        NaN            uri
# 48                                        NaN            uri
# 49                                        NaN            uri
# 50                                        NaN            uri
# 51                                        NaN            uri
# 52                                        NaN            uri
# 53                                        NaN            uri
# 54                                        NaN            uri
# 55                                        NaN            uri
# 56                                        NaN            uri
# 57                                        NaN            uri
# 58                                        NaN            uri
# 59                                        NaN            uri
# 60                                        NaN            uri
# 61                                        NaN            uri
# 62                                        NaN            uri
# 63                                        NaN            uri
# 64                                        NaN            uri
# 65                                        NaN            uri
# 66                                        NaN            uri
# 67                                        NaN            uri
# 68                                        NaN            uri
# 69                                        NaN            uri
# 70                                        NaN            uri
# 71                                        NaN            uri
# 72                                        NaN            uri
# 73                                        NaN            uri
# 74                                        NaN            uri
# 75                                        NaN            uri
# 76                                        NaN            uri
# 77                                        NaN            uri
# 78                                        NaN            uri
# 79                                        NaN            uri
# 80                                        NaN            uri
# 81                                        NaN            uri
# 82                                        NaN            uri
# 83                                        NaN            uri
# 84                                        NaN            uri
# 85                                        NaN        literal
# 86      http://www.w3.org/2001/XMLSchema#date  typed-literal
# 87                                        NaN        literal
# 88                                        NaN        literal
# 89   http://www.w3.org/2001/XMLSchema#integer  typed-literal
# 90                                        NaN        literal
# 91      http://www.w3.org/2001/XMLSchema#date  typed-literal
# 92                                        NaN        literal
# 93                                        NaN        literal
# 94                                        NaN        literal
# 95                                        NaN        literal
# 96                                        NaN            uri
# 97                                        NaN            uri
# 98                                        NaN        literal
# 99                                        NaN        literal
# 100                                       NaN        literal
# 101  http://www.w3.org/2001/XMLSchema#integer  typed-literal
# 102  http://www.w3.org/2001/XMLSchema#integer  typed-literal
# 103  http://www.w3.org/2001/XMLSchema#integer  typed-literal
# 104  http://www.w3.org/2001/XMLSchema#integer  typed-literal
# 105  http://www.w3.org/2001/XMLSchema#integer  typed-literal
# 106  http://www.w3.org/2001/XMLSchema#integer  typed-literal
# 107  http://www.w3.org/2001/XMLSchema#integer  typed-literal
# 108  http://www.w3.org/2001/XMLSchema#integer  typed-literal
# 109  http://www.w3.org/2001/XMLSchema#integer  typed-literal
# 110                                       NaN            uri
# 111                                       NaN            uri
# 112                                       NaN            uri
# 113                                       NaN        literal
# 114                                       NaN        literal
# 115                                       NaN        literal
# 116                                       NaN        literal
# 117  http://www.w3.org/2001/XMLSchema#integer  typed-literal
# 118                                       NaN        literal
# 119                                       NaN        literal
# 120                                       NaN        literal
# 121                                       NaN        literal
# 122                                       NaN        literal
# 123                                       NaN        literal
# 124                                       NaN        literal
# 125                                       NaN        literal
# 126                                       NaN        literal
# 127                                       NaN        literal
# 128                                       NaN            uri
# 129                                       NaN            uri
# 130                                       NaN            uri
# 131                                       NaN            uri
# 132                                       NaN            uri
# 133                                       NaN            uri
# 134                                       NaN            uri
# 135                                       NaN        literal
# 136                                       NaN        literal
# 137                                       NaN        literal
# 138                                       NaN        literal
# 139                                       NaN        literal
# 140                                       NaN        literal
# 141                                       NaN        literal
# 142                                       NaN        literal
# 143                                       NaN        literal
# 144                                       NaN        literal
# 145                                       NaN        literal
# 146                                       NaN            uri
# 147                                       NaN        literal
# 148                                       NaN        literal
# 149    http://www.w3.org/2001/XMLSchema#gYear  typed-literal
# 150                                       NaN        literal
# 151                                       NaN        literal
# 152     http://www.w3.org/2001/XMLSchema#date  typed-literal
# 153                                       NaN        literal
# 154    http://www.w3.org/2001/XMLSchema#gYear  typed-literal
# 155                                       NaN        literal
# 156                                       NaN        literal
# 157                                       NaN        literal
# 158  http://www.w3.org/2001/XMLSchema#integer  typed-literal
# 159                                       NaN        literal
# 160  http://www.w3.org/2001/XMLSchema#integer  typed-literal
# 161                                       NaN            uri
# 162                                       NaN            uri
# 163                                       NaN            uri
# 164                                       NaN            uri
# 165                                       NaN            uri
# 166                                       NaN            uri
# 167                                       NaN            uri
# 168                                       NaN            uri
# 169                                       NaN            uri
# 170                                       NaN            uri
# 171                                       NaN            uri
#
#                                                                                                  o.value  \
# 0                                                                    http://www.w3.org/2002/07/owl#Thing
# 1                                                                       http://xmlns.com/foaf/0.1/Person
# 2                                                                               http://schema.org/Person
# 3                                                                     http://dbpedia.org/ontology/Person
# 4                                                                      http://dbpedia.org/ontology/Agent
# 5                                                                 http://www.wikidata.org/entity/Q215627
# 6                                                                      http://www.wikidata.org/entity/Q5
# 7                                            http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#Agent
# 8                                    http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#NaturalPerson
# 9                                                                                        Martin Scorsese
# 10                                                                                        مارتن سكورسيزي
# 11                                                                                       Martin Scorsese
# 12                                                                                       Martin Scorsese
# 13                                                                                       Martin Scorsese
# 14                                                                                       Martin Scorsese
# 15                                                                                           マーティン・スコセッシ
# 16                                                                                       Martin Scorsese
# 17                                                                                       Martin Scorsese
# 18                                                                                       Martin Scorsese
# 19                                                                                      Скорсезе, Мартин
# 20                                                                                               马丁·斯科塞斯
# 21   Martin Marcantonio Luciano Scorsese [skɔɹˈsɛzɪ] (* 17. November 1942 in Queens, New York) ist ei...
# 22   マーティン・スコセッシ（Martin Scorsese, 本名: Martin Marcantonio Luciano Scorsese, 1942年11月17日 - ）は、アメリカ合衆国の映...
# 23   Martin Scorsese (Queens (New York City), 17 november 1942) is een Amerikaans filmregisseur van S...
# 24   Martin Scorsese (ur. 17 listopada 1942 w Nowym Jorku) – amerykański reżyser, scenarzysta, montaż...
# 25   Martin Scorsese (Martin Charles Scorsese, Queens, Nova Iorque, 17 de novembro de 1942) é um cine...
# 26   Martin Charles Scorsese (/skɔrˈsɛsi/; born November 17, 1942) is an American director, producer,...
# 27   مارتن سكورسيزي ولد في 17 نوفمبر 1942 نيويورك في الولايات المتحدة الأمريكية، هو مخرج سينمائي أمري...
# 28   Martin Charles Scorsese (Queens, Nueva York, 17 de noviembre de 1942), conocido como Martin Scor...
# 29   Martin Scorsese est un réalisateur américain, né le 17 novembre 1942 à New York aux États-Unis.D...
# 30   Esponente della New Hollywood, è considerato uno dei maggiori e più importanti registi della sto...
# 31   Ма́ртин Ча́рльз Скорсе́зе (англ. Martin Charles Scorsese, более точное произношение фамилии — Ск...
# 32                                                                    http://rdf.freebase.com/ns/m.04sry
# 33                                                                 http://www.wikidata.org/entity/Q41148
# 34                                                        http://fr.dbpedia.org/resource/Martin_Scorsese
# 35                                                        http://de.dbpedia.org/resource/Martin_Scorsese
# 36                                                        http://cs.dbpedia.org/resource/Martin_Scorsese
# 37                                                        http://el.dbpedia.org/resource/Μάρτιν_Σκορσέζε
# 38                                                        http://es.dbpedia.org/resource/Martin_Scorsese
# 39                                                        http://eu.dbpedia.org/resource/Martin_Scorsese
# 40                                                        http://id.dbpedia.org/resource/Martin_Scorsese
# 41                                                        http://it.dbpedia.org/resource/Martin_Scorsese
# 42                                                            http://ja.dbpedia.org/resource/マーティン・スコセッシ
# 43                                                               http://ko.dbpedia.org/resource/마틴_스코세이지
# 44                                                        http://nl.dbpedia.org/resource/Martin_Scorsese
# 45                                                        http://pl.dbpedia.org/resource/Martin_Scorsese
# 46                                                        http://pt.dbpedia.org/resource/Martin_Scorsese
# 47                                                           http://wikidata.dbpedia.org/resource/Q41148
# 48                                                      http://dbpedia.org/resource/Category:1942_births
# 49                                http://dbpedia.org/resource/Category:20th-century_American_male_actors
# 50                                http://dbpedia.org/resource/Category:21st-century_American_male_actors
# 51                                         http://dbpedia.org/resource/Category:American_Roman_Catholics
# 52                                  http://dbpedia.org/resource/Category:American_documentary_filmmakers
# 53                                          http://dbpedia.org/resource/Category:American_film_directors
# 54                       http://dbpedia.org/resource/Category:American_film_directors_of_Italian_descent
# 55                                            http://dbpedia.org/resource/Category:American_film_editors
# 56                                          http://dbpedia.org/resource/Category:American_film_producers
# 57                                        http://dbpedia.org/resource/Category:American_male_film_actors
# 58                                      http://dbpedia.org/resource/Category:American_male_screenwriters
# 59                                   http://dbpedia.org/resource/Category:American_music_video_directors
# 60                              http://dbpedia.org/resource/Category:American_people_of_Sicilian_descent
# 61                              http://dbpedia.org/resource/Category:Best_Director_Academy_Award_winners
# 62                                http://dbpedia.org/resource/Category:Best_Director_BAFTA_Award_winners
# 63                               http://dbpedia.org/resource/Category:Best_Director_Golden_Globe_winners
# 64                      http://dbpedia.org/resource/Category:Cecil_B._DeMille_Award_Golden_Globe_winners
# 65                                              http://dbpedia.org/resource/Category:César_Award_winners
# 66                          http://dbpedia.org/resource/Category:David_di_Donatello_Career_Award_winners
# 67                         http://dbpedia.org/resource/Category:Directors_Guild_of_America_Award_winners
# 68                                  http://dbpedia.org/resource/Category:English-language_film_directors
# 69             http://dbpedia.org/resource/Category:Fellows_of_the_American_Academy_of_Arts_and_Sciences
# 70                                http://dbpedia.org/resource/Category:Film_directors_from_New_York_City
# 71                                                   http://dbpedia.org/resource/Category:Film_theorists
# 72                                             http://dbpedia.org/resource/Category:Grammy_Award_winners
# 73                                          http://dbpedia.org/resource/Category:Kennedy_Center_honorees
# 74                                                    http://dbpedia.org/resource/Category:Living_people
# 75                                      http://dbpedia.org/resource/Category:Légion_d'honneur_recipients
# 76                                   http://dbpedia.org/resource/Category:Male_actors_from_New_York_City
# 77                                   http://dbpedia.org/resource/Category:Male_actors_of_Italian_descent
# 78                                               http://dbpedia.org/resource/Category:New_York_Democrats
# 79                                       http://dbpedia.org/resource/Category:People_from_Corona,_Queens
# 80                                     http://dbpedia.org/resource/Category:Primetime_Emmy_Award_winners
# 81                                  http://dbpedia.org/resource/Category:Tisch_School_of_the_Arts_alumni
# 82                          http://dbpedia.org/resource/Category:Transcendental_Meditation_practitioners
# 83                         http://dbpedia.org/resource/Category:Venice_Best_Director_Silver_Lion_winners
# 84                                                       http://dbpedia.org/resource/New_York_University
# 85                                                                                   Scorsese, Martin C.
# 86                                                                                            1942-11-17
# 87                                                                               Martin Charles Scorsese
# 88                                                                                Queens, New York, U.S.
# 89                                                                                                     3
# 90                                                                              Category:Martin Scorsese
# 91                                                                                            1942-11-17
# 92                                                                                                    no
# 93                                                                                                    no
# 94                                               Director, producer, actor, screenwriter, film historian
# 95                                                                                                 Marty
# 96                                                        http://dbpedia.org/resource/Catherine_Scorsese
# 97                                                          http://dbpedia.org/resource/Charles_Scorsese
# 98                                                                     Flushing, New York, United States
# 99                                                                                American film director
# 100                                                                                                   no
# 101                                                                                                 1965
# 102                                                                                                 1971
# 103                                                                                                 1976
# 104                                                                                                 1977
# 105                                                                                                 1979
# 106                                                                                                 1982
# 107                                                                                                 1985
# 108                                                                                                 1991
# 109                                                                                                 1999
# 110                                                      http://dbpedia.org/resource/Isabella_Rossellini
# 111                                                          http://dbpedia.org/resource/Barbara_De_Fina
# 112                                                            http://dbpedia.org/resource/Julia_Cameron
# 113                                                                            Helen Schermerhorn Morris
# 114                                                                                Laraine Marie Brennan
# 115                                                                                                 div.
# 116                                                                                                   no
# 117                                                                                                 1963
# 118                                                                                                   no
# 119                                                            Scorsese at the 2010 Cannes Film Festival
# 120                                                                                               Q41148
# 121                                                                                                   no
# 122                                                                                      Martin Scorsese
# 123                                                                                     Scorsese, Martin
# 124                                                                                                   no
# 125                                                                           Awards for Martin Scorsese
# 126                                                                                                   no
# 127                                                                                                   no
# 128                                  http://digitalcontentproducer.com/podcasts/audio/scorsese_departed/
# 129                      http://realserver.princeton.edu:8080/ramgen/lectures/19990504scorseseTV7200K.rm
# 130                                                  http://www.theyshootpictures.com/scorsesemartin.htm
# 131                                                  http://www.lib.berkeley.edu/MRC/martinscorsese.html
# 132                            http://www.vanityfair.com/culture/features/2010/03/proust-scorsese-201003
# 133                   http://commons.wikimedia.org/wiki/Special:FilePath/Martin_Scorsese_Cannes_2010.jpg
# 134         http://commons.wikimedia.org/wiki/Special:FilePath/Martin_Scorsese_Cannes_2010.jpg?width=300
# 135  Martin Charles Scorsese (/skɔrˈsɛsi/; born November 17, 1942) is an American director, producer,...
# 136  مارتن سكورسيزي ولد في 17 نوفمبر 1942 نيويورك في الولايات المتحدة الأمريكية، هو مخرج سينمائي أمري...
# 137  Martin Marcantonio Luciano Scorsese [skɔɹˈsɛzɪ] (* 17. November 1942 in Queens, New York) ist ei...
# 138  Martin Charles Scorsese (Queens, Nueva York, 17 de noviembre de 1942), conocido como Martin Scor...
# 139  Martin Scorsese est un réalisateur américain, né le 17 novembre 1942 à New York aux États-Unis.D...
# 140  Esponente della New Hollywood, è considerato uno dei maggiori e più importanti registi della sto...
# 141  マーティン・スコセッシ（Martin Scorsese, 本名: Martin Marcantonio Luciano Scorsese, 1942年11月17日 - ）は、アメリカ合衆国の映...
# 142  Martin Scorsese (Queens (New York City), 17 november 1942) is een Amerikaans filmregisseur van S...
# 143  Martin Scorsese (ur. 17 listopada 1942 w Nowym Jorku) – amerykański reżyser, scenarzysta, montaż...
# 144  Martin Scorsese (Martin Charles Scorsese, Queens, Nova Iorque, 17 de novembro de 1942) é um cine...
# 145  Ма́ртин Ча́рльз Скорсе́зе (англ. Martin Charles Scorsese, более точное произношение фамилии — Ск...
# 146                                         http://en.wikipedia.org/wiki/Martin_Scorsese?oldid=682860997
# 147                                                                               American film director
# 148                                                                               American film director
# 149                                                                            1963-01-01T00:00:00-05:00
# 150                                                                                                Marty
# 151                                                                                  Scorsese, Martin C.
# 152                                                                                           1942-11-17
# 153                                                                              Martin Charles Scorsese
# 154                                                                            1942-01-01T00:00:00-05:00
# 155                                                                                               Martin
# 156                                                                                      Martin Scorsese
# 157                                                                                     Scorsese, Martin
# 158                                                                                                18995
# 159                                                                                             Scorsese
# 160                                                                                            682860997
# 161                                                      http://dbpedia.org/resource/New_York_University
# 162                                                                   http://dbpedia.org/resource/Queens
# 163                                                         http://dbpedia.org/resource/Flushing,_Queens
# 164                                                                 http://dbpedia.org/resource/New_York
# 165                                                       http://dbpedia.org/resource/Martin_Scorsese__1
# 166                                                       http://dbpedia.org/resource/Catherine_Scorsese
# 167                                                         http://dbpedia.org/resource/Charles_Scorsese
# 168                                                      http://dbpedia.org/resource/Isabella_Rossellini
# 169                                                          http://dbpedia.org/resource/Barbara_De_Fina
# 170                                                            http://dbpedia.org/resource/Julia_Cameron
# 171                                                         http://en.wikipedia.org/wiki/Martin_Scorsese
#
#     o.xml:lang p.type                                           p.value
# 0          NaN    uri   http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 1          NaN    uri   http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 2          NaN    uri   http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 3          NaN    uri   http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 4          NaN    uri   http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 5          NaN    uri   http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 6          NaN    uri   http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 7          NaN    uri   http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 8          NaN    uri   http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 9           en    uri        http://www.w3.org/2000/01/rdf-schema#label
# 10          ar    uri        http://www.w3.org/2000/01/rdf-schema#label
# 11          de    uri        http://www.w3.org/2000/01/rdf-schema#label
# 12          es    uri        http://www.w3.org/2000/01/rdf-schema#label
# 13          fr    uri        http://www.w3.org/2000/01/rdf-schema#label
# 14          it    uri        http://www.w3.org/2000/01/rdf-schema#label
# 15          ja    uri        http://www.w3.org/2000/01/rdf-schema#label
# 16          nl    uri        http://www.w3.org/2000/01/rdf-schema#label
# 17          pl    uri        http://www.w3.org/2000/01/rdf-schema#label
# 18          pt    uri        http://www.w3.org/2000/01/rdf-schema#label
# 19          ru    uri        http://www.w3.org/2000/01/rdf-schema#label
# 20          zh    uri        http://www.w3.org/2000/01/rdf-schema#label
# 21          de    uri      http://www.w3.org/2000/01/rdf-schema#comment
# 22          ja    uri      http://www.w3.org/2000/01/rdf-schema#comment
# 23          nl    uri      http://www.w3.org/2000/01/rdf-schema#comment
# 24          pl    uri      http://www.w3.org/2000/01/rdf-schema#comment
# 25          pt    uri      http://www.w3.org/2000/01/rdf-schema#comment
# 26          en    uri      http://www.w3.org/2000/01/rdf-schema#comment
# 27          ar    uri      http://www.w3.org/2000/01/rdf-schema#comment
# 28          es    uri      http://www.w3.org/2000/01/rdf-schema#comment
# 29          fr    uri      http://www.w3.org/2000/01/rdf-schema#comment
# 30          it    uri      http://www.w3.org/2000/01/rdf-schema#comment
# 31          ru    uri      http://www.w3.org/2000/01/rdf-schema#comment
# 32         NaN    uri              http://www.w3.org/2002/07/owl#sameAs
# 33         NaN    uri              http://www.w3.org/2002/07/owl#sameAs
# 34         NaN    uri              http://www.w3.org/2002/07/owl#sameAs
# 35         NaN    uri              http://www.w3.org/2002/07/owl#sameAs
# 36         NaN    uri              http://www.w3.org/2002/07/owl#sameAs
# 37         NaN    uri              http://www.w3.org/2002/07/owl#sameAs
# 38         NaN    uri              http://www.w3.org/2002/07/owl#sameAs
# 39         NaN    uri              http://www.w3.org/2002/07/owl#sameAs
# 40         NaN    uri              http://www.w3.org/2002/07/owl#sameAs
# 41         NaN    uri              http://www.w3.org/2002/07/owl#sameAs
# 42         NaN    uri              http://www.w3.org/2002/07/owl#sameAs
# 43         NaN    uri              http://www.w3.org/2002/07/owl#sameAs
# 44         NaN    uri              http://www.w3.org/2002/07/owl#sameAs
# 45         NaN    uri              http://www.w3.org/2002/07/owl#sameAs
# 46         NaN    uri              http://www.w3.org/2002/07/owl#sameAs
# 47         NaN    uri              http://www.w3.org/2002/07/owl#sameAs
# 48         NaN    uri                  http://purl.org/dc/terms/subject
# 49         NaN    uri                  http://purl.org/dc/terms/subject
# 50         NaN    uri                  http://purl.org/dc/terms/subject
# 51         NaN    uri                  http://purl.org/dc/terms/subject
# 52         NaN    uri                  http://purl.org/dc/terms/subject
# 53         NaN    uri                  http://purl.org/dc/terms/subject
# 54         NaN    uri                  http://purl.org/dc/terms/subject
# 55         NaN    uri                  http://purl.org/dc/terms/subject
# 56         NaN    uri                  http://purl.org/dc/terms/subject
# 57         NaN    uri                  http://purl.org/dc/terms/subject
# 58         NaN    uri                  http://purl.org/dc/terms/subject
# 59         NaN    uri                  http://purl.org/dc/terms/subject
# 60         NaN    uri                  http://purl.org/dc/terms/subject
# 61         NaN    uri                  http://purl.org/dc/terms/subject
# 62         NaN    uri                  http://purl.org/dc/terms/subject
# 63         NaN    uri                  http://purl.org/dc/terms/subject
# 64         NaN    uri                  http://purl.org/dc/terms/subject
# 65         NaN    uri                  http://purl.org/dc/terms/subject
# 66         NaN    uri                  http://purl.org/dc/terms/subject
# 67         NaN    uri                  http://purl.org/dc/terms/subject
# 68         NaN    uri                  http://purl.org/dc/terms/subject
# 69         NaN    uri                  http://purl.org/dc/terms/subject
# 70         NaN    uri                  http://purl.org/dc/terms/subject
# 71         NaN    uri                  http://purl.org/dc/terms/subject
# 72         NaN    uri                  http://purl.org/dc/terms/subject
# 73         NaN    uri                  http://purl.org/dc/terms/subject
# 74         NaN    uri                  http://purl.org/dc/terms/subject
# 75         NaN    uri                  http://purl.org/dc/terms/subject
# 76         NaN    uri                  http://purl.org/dc/terms/subject
# 77         NaN    uri                  http://purl.org/dc/terms/subject
# 78         NaN    uri                  http://purl.org/dc/terms/subject
# 79         NaN    uri                  http://purl.org/dc/terms/subject
# 80         NaN    uri                  http://purl.org/dc/terms/subject
# 81         NaN    uri                  http://purl.org/dc/terms/subject
# 82         NaN    uri                  http://purl.org/dc/terms/subject
# 83         NaN    uri                  http://purl.org/dc/terms/subject
# 84         NaN    uri             http://dbpedia.org/property/almaMater
# 85          en    uri      http://dbpedia.org/property/alternativeNames
# 86         NaN    uri             http://dbpedia.org/property/birthDate
# 87          en    uri             http://dbpedia.org/property/birthName
# 88          en    uri            http://dbpedia.org/property/birthPlace
# 89         NaN    uri              http://dbpedia.org/property/children
# 90          en    uri               http://dbpedia.org/property/commons
# 91         NaN    uri           http://dbpedia.org/property/dateOfBirth
# 92          en    uri                     http://dbpedia.org/property/m
# 93          en    uri                    http://dbpedia.org/property/mw
# 94          en    uri            http://dbpedia.org/property/occupation
# 95          en    uri            http://dbpedia.org/property/otherNames
# 96         NaN    uri               http://dbpedia.org/property/parents
# 97         NaN    uri               http://dbpedia.org/property/parents
# 98          en    uri          http://dbpedia.org/property/placeOfBirth
# 99          en    uri      http://dbpedia.org/property/shortDescription
# 100         en    uri               http://dbpedia.org/property/species
# 101        NaN    uri                http://dbpedia.org/property/spouse
# 102        NaN    uri                http://dbpedia.org/property/spouse
# 103        NaN    uri                http://dbpedia.org/property/spouse
# 104        NaN    uri                http://dbpedia.org/property/spouse
# 105        NaN    uri                http://dbpedia.org/property/spouse
# 106        NaN    uri                http://dbpedia.org/property/spouse
# 107        NaN    uri                http://dbpedia.org/property/spouse
# 108        NaN    uri                http://dbpedia.org/property/spouse
# 109        NaN    uri                http://dbpedia.org/property/spouse
# 110        NaN    uri                http://dbpedia.org/property/spouse
# 111        NaN    uri                http://dbpedia.org/property/spouse
# 112        NaN    uri                http://dbpedia.org/property/spouse
# 113         en    uri                http://dbpedia.org/property/spouse
# 114         en    uri                http://dbpedia.org/property/spouse
# 115         en    uri                http://dbpedia.org/property/spouse
# 116         en    uri                  http://dbpedia.org/property/wikt
# 117        NaN    uri           http://dbpedia.org/property/yearsActive
# 118         en    uri                     http://dbpedia.org/property/b
# 119         en    uri               http://dbpedia.org/property/caption
# 120         en    uri                     http://dbpedia.org/property/d
# 121         en    uri                     http://dbpedia.org/property/n
# 122         en    uri                  http://dbpedia.org/property/name
# 123         en    uri                  http://dbpedia.org/property/name
# 124         en    uri                     http://dbpedia.org/property/s
# 125         en    uri                 http://dbpedia.org/property/title
# 126         en    uri                     http://dbpedia.org/property/v
# 127         en    uri                   http://dbpedia.org/property/voy
# 128        NaN    uri  http://dbpedia.org/ontology/wikiPageExternalLink
# 129        NaN    uri  http://dbpedia.org/ontology/wikiPageExternalLink
# 130        NaN    uri  http://dbpedia.org/ontology/wikiPageExternalLink
# 131        NaN    uri  http://dbpedia.org/ontology/wikiPageExternalLink
# 132        NaN    uri  http://dbpedia.org/ontology/wikiPageExternalLink
# 133        NaN    uri               http://xmlns.com/foaf/0.1/depiction
# 134        NaN    uri             http://dbpedia.org/ontology/thumbnail
# 135         en    uri              http://dbpedia.org/ontology/abstract
# 136         ar    uri              http://dbpedia.org/ontology/abstract
# 137         de    uri              http://dbpedia.org/ontology/abstract
# 138         es    uri              http://dbpedia.org/ontology/abstract
# 139         fr    uri              http://dbpedia.org/ontology/abstract
# 140         it    uri              http://dbpedia.org/ontology/abstract
# 141         ja    uri              http://dbpedia.org/ontology/abstract
# 142         nl    uri              http://dbpedia.org/ontology/abstract
# 143         pl    uri              http://dbpedia.org/ontology/abstract
# 144         pt    uri              http://dbpedia.org/ontology/abstract
# 145         ru    uri              http://dbpedia.org/ontology/abstract
# 146        NaN    uri          http://www.w3.org/ns/prov#wasDerivedFrom
# 147         en    uri       http://purl.org/dc/elements/1.1/description
# 148        NaN    uri       http://purl.org/dc/elements/1.1/description
# 149        NaN    uri  http://dbpedia.org/ontology/activeYearsStartYear
# 150         en    uri                 http://dbpedia.org/ontology/alias
# 151         en    uri                 http://dbpedia.org/ontology/alias
# 152        NaN    uri             http://dbpedia.org/ontology/birthDate
# 153         en    uri             http://dbpedia.org/ontology/birthName
# 154        NaN    uri             http://dbpedia.org/ontology/birthYear
# 155         en    uri               http://xmlns.com/foaf/0.1/givenName
# 156         en    uri                    http://xmlns.com/foaf/0.1/name
# 157         en    uri                    http://xmlns.com/foaf/0.1/name
# 158        NaN    uri            http://dbpedia.org/ontology/wikiPageID
# 159         en    uri                 http://xmlns.com/foaf/0.1/surname
# 160        NaN    uri    http://dbpedia.org/ontology/wikiPageRevisionID
# 161        NaN    uri             http://dbpedia.org/ontology/almaMater
# 162        NaN    uri            http://dbpedia.org/ontology/birthPlace
# 163        NaN    uri            http://dbpedia.org/ontology/birthPlace
# 164        NaN    uri            http://dbpedia.org/ontology/birthPlace
# 165        NaN    uri            http://dbpedia.org/ontology/occupation
# 166        NaN    uri                http://dbpedia.org/ontology/parent
# 167        NaN    uri                http://dbpedia.org/ontology/parent
# 168        NaN    uri                http://dbpedia.org/ontology/spouse
# 169        NaN    uri                http://dbpedia.org/ontology/spouse
# 170        NaN    uri                http://dbpedia.org/ontology/spouse
# 171        NaN    uri        http://xmlns.com/foaf/0.1/isPrimaryTopicOf
# CPU times: user 108 ms, sys: 4 ms, total: 112 ms
# Wall time: 124 ms

# %% [markdown]
# There are a total of `172` features/facts for the entity `dbr:Martin_Scorsese`. Now how do we pick features/facts to suggest entity reformulation?

# %% [markdown]
# Let us formalize the problem with the following definitions :
#
# ## Entity Features Summarization
#
# ### Entity Facts
# Let $\mathbb{E}$ be the set of entities in the RDF Graph. Then a **fact** or a **feature** $f_i$  of an entity  e $\in \mathbb{E}$, is the $\langle p, o \rangle$ pair from the triple statement $\langle e, p, o \rangle$.
#
# |Entity|Predicate|Object|
# |--|--|--|
# |**dbr:Martin_Scorsese**|**http://dbpedia.org/property/parents ** | http://dbpedia.org/resource/Charles_Scorsese	|
#
# In the above table for the entity `dbr:Martin_Scorsese` the feature $\langle p, o \rangle$ is
#
# |Predicate|Object|
# |--|--|
# |**http://dbpedia.org/property/parents** | http://dbpedia.org/resource/Charles_Scorsese	|
#
# ### Entity Fact Set
# Now entities in large graphs like DBpedia, have a lot of facts associated with them. We can denote this by the fact set of an entity $FS(e)$. The total number for `dbr:Martin_Scorsese` in this setting is `172` as we have seen.
#
#
# ### Optimal Feature Set
# While SPARQL queries can handle a lot of feature patterns, anything more than 10, would not be easy to interpret for the user. In fact heuristically most users prefer around `1-3` patterns. This is shown by the study done in in the **L**inked **S**PARQL **Q**ueries dataset. Here is how they look
#
# ![LSQ](files/images/LSQ.png)
#
# So to pick a subset of the large feature patterns, we define a **Entity Summary**.
#
# ### Entity Summary
# Given an entity $e$ from a knowledge graph and a positive integer $k$, we define an entity summary to be $k$ $\leq \mid FS(e) \mid $, entity summary of $e$, $\textit{Summ(e,k)} \subseteq \textit{FS(e)}$ such that $\mid\textit{Summ(e,k)}\mid = k$. For the example `dbr:Martin_Scorsese` we have
# * $\mid FS(e) \mid $ = `172`
#
# For $k$ = 2, here the entity summary would look like
#
# | Predicate |Object|
# |--|--|
# | **http://dbpedia.org/property/parents**    | http://dbpedia.org/resource/Charles_Scorsese	|
# | **http://dbpedia.org/ontology/birthPlace** | http://dbpedia.org/resource/Queens		|
#
# Now this entity summary can be converted to an entity summary pattern. The following table shows the entity summary pattern from the summary
#
# |Variable|Predicate|Object|
# |--|--|--|
# |?e|**http://dbpedia.org/property/parents** | http://dbpedia.org/resource/Charles_Scorsese	|
# |?e|**http://dbpedia.org/ontology/birthPlace** | http://dbpedia.org/resource/Queens		|
#
# In plain English, the $k=2$ summary can be stated as _Entity Martin Scorsese who has parents Charles Scorsese and birth place Queens_.
#
# The summary pattern can be stated as _Any entity ?e that has parents Charles Scorsese and birth place Queens_.
#
# ### Picking Summary Sets
#
# In the $k=2$ summary pattern for `dbr:Martin_Scorsese` we see that `parent, Charles Scorsese` is too specific, because very few entities can have `Charles Scorsese` as parent. Similarly `birthPlace, Queens` is more generic becaue many entities can have `Queens` as a birth place. Ideally one should be able to pick features for reformulation that
# * Is not too specific because that would end up not giving more results. This defeats the purpose of reformulation.
# * Is not too generic because that would give up a lot of results and not make it any better than relaxation.
#
# Ideally we want a function for the facts  $\left\lbrace f_1,f_2,\ldots f_k \right\rbrace $ in the fact set $\textit{FS(e)}$ so that they are ranked _ideally_ with a _ranking_ function such that $Rank(f_1) > Rank(f_2) > \ldots Rank(f_k)$. This _ranking function_ should be able to address the concerns of not being too _specifc_ or being too _generic_. We discuss how this can be achieved now.
#
#
# ### Ranking Entity Facts
#
# We introduce two measures that can be combined to produce a _ranking_ to give a summary. While there can be many ranking functions that can be developed, our goal is to first start with a ranking function to solve the entity reformulation problem. We will then explore further how we can design better ranking functions. So the two measures that we define are
# ####  Specificity :
# To pick features that convey _interesting_ information about the entity $e$ from the feature set $FS(e)$. For example `birthPlace, Queens` is not as interesting as `almaMater, New York University`. Borrowing from the world of Information Retrieval, we define _specificity_ of a feature $f_i$ based on **IDF** as follows :
#
#
# $$ \begin{align}
# \mbox{Specificity($f_i$)} = \log {\frac{\mid E \mid }{\mid e \mid \exists p,o:\langle e,p,o \rangle \in R\mid }}
# \end{align} $$
#
# Github sometimes doesn't render this so the image is here : ![specificity](files/images/specificity.png)
# Here $\mid E \mid$ refers to the total number of entity resources in the knowledge graph R.
#
# **Note:** For this paper we utilize only entity resources, so we filter out any feature $f_i$ that has literal values.
#
# Let us now apply this to `dbr:Martin_Scorsese` to see the kind of features we get.

# %%
endpoint = "http://zen.cs.rpi.edu:8890/sparql"

def specificity(column):
    return np.log(4641890/(float(column)))

def execute_augmented_query(sparqlQuery,endpoint):
    sparql = SPARQLWrapper(endpoint)
    sparql.setQuery(sparqlQuery)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    results_df = json_normalize(results["results"]["bindings"])
#     print(results_df)
    results_df = results_df[results_df['o.type'] == "uri"]
    results_df = results_df.drop(['o.type','p.type'],axis=1)
    results_df = results_df[['p.value','o.value','countS.value']]
    results_df['countS.value'] = results_df['countS.value'].astype(int)
#     results_df = results_df[results_df['countS.value']]
    return results_df

## This query is used to find the count values for the 'Specificity'.
augmented_query = """
PREFIX  schema: <http://schema.org/>
PREFIX  dbr:  <http://dbpedia.org/resource/>
PREFIX  umbel-rc: <http://umbel.org/umbel/rc/>
PREFIX  dbc:  <http://dbpedia.org/resource/Category:>
PREFIX  owl:  <http://www.w3.org/2002/07/owl#>
PREFIX  yago: <http://dbpedia.org/class/yago/>
PREFIX  rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX  dbo:  <http://dbpedia.org/ontology/>
PREFIX  dbp:  <http://dbpedia.org/property/>
PREFIX  rdf:  <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX  dcterms: <http://purl.org/dc/terms/>
PREFIX  dbpedia-wikidata: <http://wikidata.dbpedia.org/resource/>
PREFIX  dul:  <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
PREFIX  foaf: <http://xmlns.com/foaf/0.1/>
PREFIX  dc:   <http://purl.org/dc/elements/1.1/>
PREFIX prov: <http://www.w3.org/ns/prov#>
PREFIX  dc: <http://purl.org/dc/elements/1.1/>

SELECT  ?p ?o (COUNT(DISTINCT ?s) AS ?countS)
WHERE
  { dbr:Martin_Scorsese
              # ?p  ?o .
    # ?s        ?p  ?o
    FILTER ( ! strstarts(str(?p), str(dbo:wikiPageWikiLink)) )
    FILTER ( ! strstarts(str(?p), str(dbo:wikiPageID)) )
    FILTER ( ! strstarts(str(?p), str(dbo:wikiPageExternalLink)) )
    FILTER ( ! strstarts(str(?p), str(dbo:wikiPageRevisionID)) )
    FILTER ( ! strstarts(str(?p), str(dbo:wikiPageLength)) )
    FILTER ( ! strstarts(str(?p), str(owl:sameAs)) )
    FILTER ( ! strstarts(str(?p), str(dbo:viafId)) )
    FILTER ( ! strstarts(str(?p), str(dbo:wikiPageOutDegree)) )
    FILTER ( ! strstarts(str(?p), str(schema:comment)) )
    FILTER ( ! strstarts(str(?p), str(dbo:abstract)) )
    FILTER ( ! strstarts(str(?p), str(rdfs:comment)) )
    FILTER ( ! strstarts(str(?p), str(dbo:alias)) )
    FILTER ( ! strstarts(str(?p), str(rdfs:label)) )
    FILTER ( ! strstarts(str(?p), str(dbo:thumbnail)) )
    FILTER ( ! strstarts(str(?p), str(foaf:name)) )
    FILTER ( ! strstarts(str(?p), str(foaf:surname)) )
    FILTER ( ! strstarts(str(?p), str(foaf:depiction)) )
    FILTER ( ! strstarts(str(?p), str(foaf:isPrimaryTopicOf)) )
    FILTER ( ! strstarts(str(?p), str(dbp:hasPhotoCollection)) )
    FILTER ( ! strstarts(str(?p), str(dbp:wordnet_type)) )
    FILTER ( ! strstarts(str(?p), str(prov:wasDerivedFrom)) )
    FILTER ( ! strstarts(str(?p), str(dc:description)) )
   
    
    
  }
GROUP BY ?p ?o
ORDER BY ASC(?countS)
"""
results_df = execute_augmented_query(augmented_query,endpoint)
results_df.reset_index(inplace=True)
results_df['Specificity'] = results_df['countS.value'].apply(specificity)
results_df.sort_values(by=['Specificity'],ascending=False,inplace=True)
display(results_df)
# Out:
#     index                                          p.value  \
# 0       0               http://dbpedia.org/ontology/spouse
# 2       6               http://dbpedia.org/ontology/parent
# 3       7               http://dbpedia.org/property/spouse
# 4       9               http://dbpedia.org/ontology/spouse
# 5      10               http://dbpedia.org/property/spouse
# 6      11               http://dbpedia.org/property/spouse
# 7      12           http://dbpedia.org/ontology/occupation
# 8      15              http://dbpedia.org/property/parents
# 9      18               http://dbpedia.org/ontology/spouse
# 10     21              http://dbpedia.org/property/parents
# 1       5               http://dbpedia.org/ontology/parent
# 11     26                 http://purl.org/dc/terms/subject
# 12     29                 http://purl.org/dc/terms/subject
# 13     31                 http://purl.org/dc/terms/subject
# 14     32                 http://purl.org/dc/terms/subject
# 16     34                 http://purl.org/dc/terms/subject
# 15     33                 http://purl.org/dc/terms/subject
# 17     35                 http://purl.org/dc/terms/subject
# 18     37                 http://purl.org/dc/terms/subject
# 19     38           http://dbpedia.org/ontology/birthPlace
# 20     46                 http://purl.org/dc/terms/subject
# 21     48                 http://purl.org/dc/terms/subject
# 22     50                 http://purl.org/dc/terms/subject
# 23     51                 http://purl.org/dc/terms/subject
# 24     52                 http://purl.org/dc/terms/subject
# 25     53                 http://purl.org/dc/terms/subject
# 26     54                 http://purl.org/dc/terms/subject
# 27     55                 http://purl.org/dc/terms/subject
# 28     57                 http://purl.org/dc/terms/subject
# 29     58            http://dbpedia.org/property/almaMater
# 30     59                 http://purl.org/dc/terms/subject
# 31     60                 http://purl.org/dc/terms/subject
# 32     63            http://dbpedia.org/ontology/almaMater
# 33     64           http://dbpedia.org/ontology/birthPlace
# 34     65                 http://purl.org/dc/terms/subject
# 35     66                 http://purl.org/dc/terms/subject
# 36     67                 http://purl.org/dc/terms/subject
# 37     68                 http://purl.org/dc/terms/subject
# 38     74                 http://purl.org/dc/terms/subject
# 39     77                 http://purl.org/dc/terms/subject
# 40     78                 http://purl.org/dc/terms/subject
# 41     81                 http://purl.org/dc/terms/subject
# 42     82                 http://purl.org/dc/terms/subject
# 43     84                 http://purl.org/dc/terms/subject
# 44     85                 http://purl.org/dc/terms/subject
# 45     86                 http://purl.org/dc/terms/subject
# 46     88                 http://purl.org/dc/terms/subject
# 47     89                 http://purl.org/dc/terms/subject
# 48     91           http://dbpedia.org/ontology/birthPlace
# 49     92                 http://purl.org/dc/terms/subject
# 50     93                 http://purl.org/dc/terms/subject
# 51     94                 http://purl.org/dc/terms/subject
# 52     95  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 53     96  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 54     97  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 55     98  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 56     99  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 57    100  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 58    101  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 59    102  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 60    103  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
#
#                                                                                       o.value  \
# 0                                                   http://dbpedia.org/resource/Julia_Cameron
# 2                                              http://dbpedia.org/resource/Catherine_Scorsese
# 3                                             http://dbpedia.org/resource/Isabella_Rossellini
# 4                                             http://dbpedia.org/resource/Isabella_Rossellini
# 5                                                   http://dbpedia.org/resource/Julia_Cameron
# 6                                                 http://dbpedia.org/resource/Barbara_De_Fina
# 7                                              http://dbpedia.org/resource/Martin_Scorsese__1
# 8                                                http://dbpedia.org/resource/Charles_Scorsese
# 9                                                 http://dbpedia.org/resource/Barbara_De_Fina
# 10                                             http://dbpedia.org/resource/Catherine_Scorsese
# 1                                                http://dbpedia.org/resource/Charles_Scorsese
# 11              http://dbpedia.org/resource/Category:Venice_Best_Director_Silver_Lion_winners
# 12                            http://dbpedia.org/resource/Category:People_from_Corona,_Queens
# 13                     http://dbpedia.org/resource/Category:Best_Director_BAFTA_Award_winners
# 14               http://dbpedia.org/resource/Category:David_di_Donatello_Career_Award_winners
# 16                    http://dbpedia.org/resource/Category:Best_Director_Golden_Globe_winners
# 15            http://dbpedia.org/resource/Category:American_film_directors_of_Italian_descent
# 17           http://dbpedia.org/resource/Category:Cecil_B._DeMille_Award_Golden_Globe_winners
# 18                   http://dbpedia.org/resource/Category:Best_Director_Academy_Award_winners
# 19                                               http://dbpedia.org/resource/Flushing,_Queens
# 20                                   http://dbpedia.org/resource/Category:César_Award_winners
# 21                                        http://dbpedia.org/resource/Category:Film_theorists
# 22              http://dbpedia.org/resource/Category:Directors_Guild_of_America_Award_winners
# 23                               http://dbpedia.org/resource/Category:Kennedy_Center_honorees
# 24                     http://dbpedia.org/resource/Category:Film_directors_from_New_York_City
# 25               http://dbpedia.org/resource/Category:Transcendental_Meditation_practitioners
# 26                   http://dbpedia.org/resource/Category:American_people_of_Sicilian_descent
# 27                        http://dbpedia.org/resource/Category:American_music_video_directors
# 28                          http://dbpedia.org/resource/Category:Primetime_Emmy_Award_winners
# 29                                            http://dbpedia.org/resource/New_York_University
# 30                                 http://dbpedia.org/resource/Category:American_film_editors
# 31                       http://dbpedia.org/resource/Category:English-language_film_directors
# 32                                            http://dbpedia.org/resource/New_York_University
# 33                                                         http://dbpedia.org/resource/Queens
# 34                       http://dbpedia.org/resource/Category:American_documentary_filmmakers
# 35                        http://dbpedia.org/resource/Category:Male_actors_of_Italian_descent
# 36                       http://dbpedia.org/resource/Category:Tisch_School_of_the_Arts_alumni
# 37                           http://dbpedia.org/resource/Category:Légion_d'honneur_recipients
# 38                        http://dbpedia.org/resource/Category:Male_actors_from_New_York_City
# 39  http://dbpedia.org/resource/Category:Fellows_of_the_American_Academy_of_Arts_and_Sciences
# 40                                    http://dbpedia.org/resource/Category:New_York_Democrats
# 41                                  http://dbpedia.org/resource/Category:Grammy_Award_winners
# 42                              http://dbpedia.org/resource/Category:American_Roman_Catholics
# 43                     http://dbpedia.org/resource/Category:21st-century_American_male_actors
# 44                               http://dbpedia.org/resource/Category:American_film_producers
# 45                           http://dbpedia.org/resource/Category:American_male_screenwriters
# 46                               http://dbpedia.org/resource/Category:American_film_directors
# 47                     http://dbpedia.org/resource/Category:20th-century_American_male_actors
# 48                                                       http://dbpedia.org/resource/New_York
# 49                                           http://dbpedia.org/resource/Category:1942_births
# 50                             http://dbpedia.org/resource/Category:American_male_film_actors
# 51                                         http://dbpedia.org/resource/Category:Living_people
# 52                                                         http://dbpedia.org/ontology/Person
# 53                                                     http://www.wikidata.org/entity/Q215627
# 54                                                          http://www.wikidata.org/entity/Q5
# 55                                                                   http://schema.org/Person
# 56                        http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#NaturalPerson
# 57                                                           http://xmlns.com/foaf/0.1/Person
# 58                                                          http://dbpedia.org/ontology/Agent
# 59                                http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#Agent
# 60                                                        http://www.w3.org/2002/07/owl#Thing
#
#     countS.value  Specificity
# 0              1    15.350632
# 2              1    15.350632
# 3              1    15.350632
# 4              1    15.350632
# 5              1    15.350632
# 6              1    15.350632
# 7              1    15.350632
# 8              1    15.350632
# 9              1    15.350632
# 10             1    15.350632
# 1              1    15.350632
# 11            19    12.406193
# 12            24    12.172578
# 13            38    11.713046
# 14            45    11.543970
# 16            52    11.399388
# 15            52    11.399388
# 17            62    11.223498
# 18            68    11.131124
# 19            88    10.873295
# 20           137    10.430651
# 21           155    10.307207
# 22           184    10.135696
# 23           188    10.114190
# 24           198    10.062365
# 25           212     9.994046
# 26           267     9.763384
# 27           372     9.431738
# 28           431     9.284524
# 29           498     9.140032
# 30           503     9.130042
# 31           520     9.096803
# 32           581     8.985881
# 33           595     8.962071
# 34           649     8.875199
# 35           726     8.763082
# 36           817     8.644993
# 37           885     8.565045
# 38          1454     8.068559
# 39          1864     7.820152
# 40          1966     7.766876
# 41          2389     7.572002
# 42          2393     7.570329
# 43          3465     7.200164
# 44          3489     7.193262
# 45          3608     7.159723
# 46          4477     6.943924
# 47          6540     6.564940
# 48          8078     6.353733
# 49          8423     6.311911
# 50         10374     6.103574
# 51        729176     1.850962
# 52       1587944     1.072682
# 53       1587944     1.072682
# 54       1587944     1.072682
# 55       1587944     1.072682
# 56       1587944     1.072682
# 57       1588593     1.072273
# 58       1855262     0.917096
# 59       1855262     0.917096
# 60       4995959    -0.073508

# %% [markdown]
# In the above table we see from the column **countS.value** that properties like `http://dbpedia.org/ontology/spouse	` and `http://dbpedia.org/ontology/parents` are very specific and using them to reformulate will not lead us to any new results. For example let us use `http://dbpedia.org/ontology/spouse, http://dbpedia.org/resource/Barbara_De_Fina` to reformulate. The triple pattern for this becomes
# `?e http://dbpedia.org/ontology/spouse http://dbpedia.org/resource/Barbara_De_Fina`. Appending this to the original query we	get the following query
# ```
# Select
# ?movie dbo:director ?e
# ?e http://dbpedia.org/ontology/spouse http://dbpedia.org/resource/Barbara_De_Fina .
# ```
#
# The query translates in plain english as _Select all movies that are directed by an entity that has spouse Barbara De Fina_. This kind of a feature is too specific for just `dbr:Martin_Scorsese`. So we would need some other measure to pick features that are related to the entity and give more results, but aren't too generic. In addition we need to remove features that have **countS.value** = 1.
#
# ### Popularity
#
# Since it is the value i.e. the $o$ in $\langle p, o \rangle$ that contributes to being selective, we consider the notion of _popularity_, which is inspired by **TF** or is a weighting term. This utilizes the value $o_i$ frequency of a feature $f_i$ which is nothing but the tuple $\langle p_i, o_i \rangle$ and can be defined as :
# $$
# \begin{align}
# \mbox{Popularity($o_i$)}  = \log {\mid t \mid \exists o_i:\langle e,p,o_i \rangle \in R\mid }
# \end{align}
# $$
#
# If the formula hasn't been rendered here is the image ![popularity](files/images/popularity.png)
# ### Combined Ranking for Features
#
# Now that we have _popularity_ and _specificity_ we combine them to form the combined ranking for a feature $f_i$. So the ranking function for a feature $f_i = \langle p_i, o_i \rangle$  can be defined as :
#
# $$
# \begin{align}
# \mbox{Rank($f_i$)}  = Specificity(f_i) * Popularity(o_i)
# \end{align}
# $$
# If the formula hasn't been rendered here is the image ![rank](files/images/rank.png)
# Let us apply this and see in real time how this changes the object values.

# %%
import math
def nbycount(column):
    return 4641890/(1+float(column))

def execute_count_query(obj):
    if(obj.startswith('http')):
        sparqlQuery = "Select (count(*) as ?countRow)  WHERE { ?s " + "?p  <" + obj + "> }"       
    else:
        sparqlQuery = 'Select (count(*) as ?countRow)  WHERE { ?s ' + '?p "' + obj + '"}'
        
    sparql = SPARQLWrapper("http://zen.cs.rpi.edu:8890/sparql")
    sparql.setQuery(sparqlQuery)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    results_df = json_normalize(results["results"]["bindings"])
    val = float(results_df['countRow.value'])
    return val
results_df = results_df[results_df['countS.value'] > 1]
results_df['Popularity'] = results_df['o.value'].apply(execute_count_query)
results_df['Popularity'] = results_df['Popularity'].apply(math.log)
results_df.sort_values(by=['Popularity'],ascending=True,inplace=True)
display(results_df)
# Out:
#     index                                          p.value  \
# 11     26                 http://purl.org/dc/terms/subject
# 12     29                 http://purl.org/dc/terms/subject
# 13     31                 http://purl.org/dc/terms/subject
# 14     32                 http://purl.org/dc/terms/subject
# 15     33                 http://purl.org/dc/terms/subject
# 16     34                 http://purl.org/dc/terms/subject
# 17     35                 http://purl.org/dc/terms/subject
# 18     37                 http://purl.org/dc/terms/subject
# 20     46                 http://purl.org/dc/terms/subject
# 21     48                 http://purl.org/dc/terms/subject
# 22     50                 http://purl.org/dc/terms/subject
# 23     51                 http://purl.org/dc/terms/subject
# 24     52                 http://purl.org/dc/terms/subject
# 25     53                 http://purl.org/dc/terms/subject
# 26     54                 http://purl.org/dc/terms/subject
# 27     55                 http://purl.org/dc/terms/subject
# 19     38           http://dbpedia.org/ontology/birthPlace
# 28     57                 http://purl.org/dc/terms/subject
# 30     59                 http://purl.org/dc/terms/subject
# 31     60                 http://purl.org/dc/terms/subject
# 34     65                 http://purl.org/dc/terms/subject
# 35     66                 http://purl.org/dc/terms/subject
# 36     67                 http://purl.org/dc/terms/subject
# 37     68                 http://purl.org/dc/terms/subject
# 38     74                 http://purl.org/dc/terms/subject
# 29     58            http://dbpedia.org/property/almaMater
# 32     63            http://dbpedia.org/ontology/almaMater
# 39     77                 http://purl.org/dc/terms/subject
# 40     78                 http://purl.org/dc/terms/subject
# 33     64           http://dbpedia.org/ontology/birthPlace
# 41     81                 http://purl.org/dc/terms/subject
# 42     82                 http://purl.org/dc/terms/subject
# 43     84                 http://purl.org/dc/terms/subject
# 44     85                 http://purl.org/dc/terms/subject
# 45     86                 http://purl.org/dc/terms/subject
# 46     88                 http://purl.org/dc/terms/subject
# 47     89                 http://purl.org/dc/terms/subject
# 49     92                 http://purl.org/dc/terms/subject
# 50     93                 http://purl.org/dc/terms/subject
# 48     91           http://dbpedia.org/ontology/birthPlace
# 51     94                 http://purl.org/dc/terms/subject
# 53     96  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 54     97  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 55     98  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 56     99  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 52     95  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 57    100  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 59    102  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 58    101  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 60    103  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
#
#                                                                                       o.value  \
# 11              http://dbpedia.org/resource/Category:Venice_Best_Director_Silver_Lion_winners
# 12                            http://dbpedia.org/resource/Category:People_from_Corona,_Queens
# 13                     http://dbpedia.org/resource/Category:Best_Director_BAFTA_Award_winners
# 14               http://dbpedia.org/resource/Category:David_di_Donatello_Career_Award_winners
# 15            http://dbpedia.org/resource/Category:American_film_directors_of_Italian_descent
# 16                    http://dbpedia.org/resource/Category:Best_Director_Golden_Globe_winners
# 17           http://dbpedia.org/resource/Category:Cecil_B._DeMille_Award_Golden_Globe_winners
# 18                   http://dbpedia.org/resource/Category:Best_Director_Academy_Award_winners
# 20                                   http://dbpedia.org/resource/Category:César_Award_winners
# 21                                        http://dbpedia.org/resource/Category:Film_theorists
# 22              http://dbpedia.org/resource/Category:Directors_Guild_of_America_Award_winners
# 23                               http://dbpedia.org/resource/Category:Kennedy_Center_honorees
# 24                     http://dbpedia.org/resource/Category:Film_directors_from_New_York_City
# 25               http://dbpedia.org/resource/Category:Transcendental_Meditation_practitioners
# 26                   http://dbpedia.org/resource/Category:American_people_of_Sicilian_descent
# 27                        http://dbpedia.org/resource/Category:American_music_video_directors
# 19                                               http://dbpedia.org/resource/Flushing,_Queens
# 28                          http://dbpedia.org/resource/Category:Primetime_Emmy_Award_winners
# 30                                 http://dbpedia.org/resource/Category:American_film_editors
# 31                       http://dbpedia.org/resource/Category:English-language_film_directors
# 34                       http://dbpedia.org/resource/Category:American_documentary_filmmakers
# 35                        http://dbpedia.org/resource/Category:Male_actors_of_Italian_descent
# 36                       http://dbpedia.org/resource/Category:Tisch_School_of_the_Arts_alumni
# 37                           http://dbpedia.org/resource/Category:Légion_d'honneur_recipients
# 38                        http://dbpedia.org/resource/Category:Male_actors_from_New_York_City
# 29                                            http://dbpedia.org/resource/New_York_University
# 32                                            http://dbpedia.org/resource/New_York_University
# 39  http://dbpedia.org/resource/Category:Fellows_of_the_American_Academy_of_Arts_and_Sciences
# 40                                    http://dbpedia.org/resource/Category:New_York_Democrats
# 33                                                         http://dbpedia.org/resource/Queens
# 41                                  http://dbpedia.org/resource/Category:Grammy_Award_winners
# 42                              http://dbpedia.org/resource/Category:American_Roman_Catholics
# 43                     http://dbpedia.org/resource/Category:21st-century_American_male_actors
# 44                               http://dbpedia.org/resource/Category:American_film_producers
# 45                           http://dbpedia.org/resource/Category:American_male_screenwriters
# 46                               http://dbpedia.org/resource/Category:American_film_directors
# 47                     http://dbpedia.org/resource/Category:20th-century_American_male_actors
# 49                                           http://dbpedia.org/resource/Category:1942_births
# 50                             http://dbpedia.org/resource/Category:American_male_film_actors
# 48                                                       http://dbpedia.org/resource/New_York
# 51                                         http://dbpedia.org/resource/Category:Living_people
# 53                                                     http://www.wikidata.org/entity/Q215627
# 54                                                          http://www.wikidata.org/entity/Q5
# 55                                                                   http://schema.org/Person
# 56                        http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#NaturalPerson
# 52                                                         http://dbpedia.org/ontology/Person
# 57                                                           http://xmlns.com/foaf/0.1/Person
# 59                                http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#Agent
# 58                                                          http://dbpedia.org/ontology/Agent
# 60                                                        http://www.w3.org/2002/07/owl#Thing
#
#     countS.value  Specificity  Popularity
# 11            19    12.406193    2.944439
# 12            24    12.172578    3.178054
# 13            38    11.713046    3.637586
# 14            45    11.543970    3.806662
# 15            52    11.399388    3.951244
# 16            52    11.399388    3.970292
# 17            62    11.223498    4.127134
# 18            68    11.131124    4.234107
# 20           137    10.430651    4.983607
# 21           155    10.307207    5.043425
# 22           184    10.135696    5.214936
# 23           188    10.114190    5.247024
# 24           198    10.062365    5.288267
# 25           212     9.994046    5.356586
# 26           267     9.763384    5.598422
# 27           372     9.431738    5.921578
# 19            88    10.873295    6.011267
# 28           431     9.284524    6.109248
# 30           503     9.130042    6.222576
# 31           520     9.096803    6.257668
# 34           649     8.875199    6.476972
# 35           726     8.763082    6.587550
# 36           817     8.644993    6.705639
# 37           885     8.565045    6.796824
# 38          1454     8.068559    7.282761
# 29           498     9.140032    7.423568
# 32           581     8.985881    7.423568
# 39          1864     7.820152    7.531016
# 40          1966     7.766876    7.584773
# 33           595     8.962071    7.755767
# 41          2389     7.572002    7.779467
# 42          2393     7.570329    7.787382
# 43          3465     7.200164    8.151045
# 44          3489     7.193262    8.158516
# 45          3608     7.159723    8.191186
# 46          4477     6.943924    8.408940
# 47          6540     6.564940    8.786151
# 49          8423     6.311911    9.038721
# 50         10374     6.103574    9.247443
# 48          8078     6.353733   10.642826
# 51        729176     1.850962   13.499699
# 53       1587944     1.072682   14.277952
# 54       1587944     1.072682   14.277952
# 55       1587944     1.072682   14.277952
# 56       1587944     1.072682   14.277952
# 52       1587944     1.072682   14.278273
# 57       1588593     1.072273   14.278386
# 59       1855262     0.917096   14.433537
# 58       1855262     0.917096   14.433553
# 60       4995959    -0.073508   15.424158

# %% [markdown]
# Clearly from the above results, we see that the most popular object values are ranked higher. Let us now use this to determine the combined ranking and then pick features:

# %%
results_df['Rank'] = results_df['Specificity'] * results_df['Popularity']
results_df.sort_values(by=['Rank'],ascending=False,inplace=True)
display(results_df)
# Out:
#     index                                          p.value  \
# 33     64           http://dbpedia.org/ontology/birthPlace
# 29     58            http://dbpedia.org/property/almaMater
# 48     91           http://dbpedia.org/ontology/birthPlace
# 32     63            http://dbpedia.org/ontology/almaMater
# 19     38           http://dbpedia.org/ontology/birthPlace
# 42     82                 http://purl.org/dc/terms/subject
# 40     78                 http://purl.org/dc/terms/subject
# 41     81                 http://purl.org/dc/terms/subject
# 39     77                 http://purl.org/dc/terms/subject
# 38     74                 http://purl.org/dc/terms/subject
# 43     84                 http://purl.org/dc/terms/subject
# 44     85                 http://purl.org/dc/terms/subject
# 45     86                 http://purl.org/dc/terms/subject
# 46     88                 http://purl.org/dc/terms/subject
# 37     68                 http://purl.org/dc/terms/subject
# 36     67                 http://purl.org/dc/terms/subject
# 35     66                 http://purl.org/dc/terms/subject
# 47     89                 http://purl.org/dc/terms/subject
# 34     65                 http://purl.org/dc/terms/subject
# 49     92                 http://purl.org/dc/terms/subject
# 31     60                 http://purl.org/dc/terms/subject
# 30     59                 http://purl.org/dc/terms/subject
# 28     57                 http://purl.org/dc/terms/subject
# 50     93                 http://purl.org/dc/terms/subject
# 27     55                 http://purl.org/dc/terms/subject
# 26     54                 http://purl.org/dc/terms/subject
# 25     53                 http://purl.org/dc/terms/subject
# 24     52                 http://purl.org/dc/terms/subject
# 23     51                 http://purl.org/dc/terms/subject
# 22     50                 http://purl.org/dc/terms/subject
# 21     48                 http://purl.org/dc/terms/subject
# 20     46                 http://purl.org/dc/terms/subject
# 18     37                 http://purl.org/dc/terms/subject
# 17     35                 http://purl.org/dc/terms/subject
# 16     34                 http://purl.org/dc/terms/subject
# 15     33                 http://purl.org/dc/terms/subject
# 14     32                 http://purl.org/dc/terms/subject
# 13     31                 http://purl.org/dc/terms/subject
# 12     29                 http://purl.org/dc/terms/subject
# 11     26                 http://purl.org/dc/terms/subject
# 51     94                 http://purl.org/dc/terms/subject
# 52     95  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 53     96  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 54     97  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 55     98  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 56     99  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 57    100  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 58    101  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 59    102  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 60    103  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
#
#                                                                                       o.value  \
# 33                                                         http://dbpedia.org/resource/Queens
# 29                                            http://dbpedia.org/resource/New_York_University
# 48                                                       http://dbpedia.org/resource/New_York
# 32                                            http://dbpedia.org/resource/New_York_University
# 19                                               http://dbpedia.org/resource/Flushing,_Queens
# 42                              http://dbpedia.org/resource/Category:American_Roman_Catholics
# 40                                    http://dbpedia.org/resource/Category:New_York_Democrats
# 41                                  http://dbpedia.org/resource/Category:Grammy_Award_winners
# 39  http://dbpedia.org/resource/Category:Fellows_of_the_American_Academy_of_Arts_and_Sciences
# 38                        http://dbpedia.org/resource/Category:Male_actors_from_New_York_City
# 43                     http://dbpedia.org/resource/Category:21st-century_American_male_actors
# 44                               http://dbpedia.org/resource/Category:American_film_producers
# 45                           http://dbpedia.org/resource/Category:American_male_screenwriters
# 46                               http://dbpedia.org/resource/Category:American_film_directors
# 37                           http://dbpedia.org/resource/Category:Légion_d'honneur_recipients
# 36                       http://dbpedia.org/resource/Category:Tisch_School_of_the_Arts_alumni
# 35                        http://dbpedia.org/resource/Category:Male_actors_of_Italian_descent
# 47                     http://dbpedia.org/resource/Category:20th-century_American_male_actors
# 34                       http://dbpedia.org/resource/Category:American_documentary_filmmakers
# 49                                           http://dbpedia.org/resource/Category:1942_births
# 31                       http://dbpedia.org/resource/Category:English-language_film_directors
# 30                                 http://dbpedia.org/resource/Category:American_film_editors
# 28                          http://dbpedia.org/resource/Category:Primetime_Emmy_Award_winners
# 50                             http://dbpedia.org/resource/Category:American_male_film_actors
# 27                        http://dbpedia.org/resource/Category:American_music_video_directors
# 26                   http://dbpedia.org/resource/Category:American_people_of_Sicilian_descent
# 25               http://dbpedia.org/resource/Category:Transcendental_Meditation_practitioners
# 24                     http://dbpedia.org/resource/Category:Film_directors_from_New_York_City
# 23                               http://dbpedia.org/resource/Category:Kennedy_Center_honorees
# 22              http://dbpedia.org/resource/Category:Directors_Guild_of_America_Award_winners
# 21                                        http://dbpedia.org/resource/Category:Film_theorists
# 20                                   http://dbpedia.org/resource/Category:César_Award_winners
# 18                   http://dbpedia.org/resource/Category:Best_Director_Academy_Award_winners
# 17           http://dbpedia.org/resource/Category:Cecil_B._DeMille_Award_Golden_Globe_winners
# 16                    http://dbpedia.org/resource/Category:Best_Director_Golden_Globe_winners
# 15            http://dbpedia.org/resource/Category:American_film_directors_of_Italian_descent
# 14               http://dbpedia.org/resource/Category:David_di_Donatello_Career_Award_winners
# 13                     http://dbpedia.org/resource/Category:Best_Director_BAFTA_Award_winners
# 12                            http://dbpedia.org/resource/Category:People_from_Corona,_Queens
# 11              http://dbpedia.org/resource/Category:Venice_Best_Director_Silver_Lion_winners
# 51                                         http://dbpedia.org/resource/Category:Living_people
# 52                                                         http://dbpedia.org/ontology/Person
# 53                                                     http://www.wikidata.org/entity/Q215627
# 54                                                          http://www.wikidata.org/entity/Q5
# 55                                                                   http://schema.org/Person
# 56                        http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#NaturalPerson
# 57                                                           http://xmlns.com/foaf/0.1/Person
# 58                                                          http://dbpedia.org/ontology/Agent
# 59                                http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#Agent
# 60                                                        http://www.w3.org/2002/07/owl#Thing
#
#     countS.value  Specificity  Popularity       Rank
# 33           595     8.962071    7.755767  69.507734
# 29           498     9.140032    7.423568  67.851654
# 48          8078     6.353733   10.642826  67.621672
# 32           581     8.985881    7.423568  66.707306
# 19            88    10.873295    6.011267  65.362283
# 42          2393     7.570329    7.787382  58.953045
# 40          1966     7.766876    7.584773  58.909991
# 41          2389     7.572002    7.779467  58.906140
# 39          1864     7.820152    7.531016  58.893694
# 38          1454     8.068559    7.282761  58.761385
# 43          3465     7.200164    8.151045  58.688862
# 44          3489     7.193262    8.158516  58.686343
# 45          3608     7.159723    8.191186  58.646625
# 46          4477     6.943924    8.408940  58.391035
# 37           885     8.565045    6.796824  58.215098
# 36           817     8.644993    6.705639  57.970204
# 35           726     8.763082    6.587550  57.727242
# 47          6540     6.564940    8.786151  57.680552
# 34           649     8.875199    6.476972  57.484422
# 49          8423     6.311911    9.038721  57.051603
# 31           520     9.096803    6.257668  56.924772
# 30           503     9.130042    6.222576  56.812383
# 28           431     9.284524    6.109248  56.721456
# 50         10374     6.103574    9.247443  56.442457
# 27           372     9.431738    5.921578  55.850778
# 26           267     9.763384    5.598422  54.659541
# 25           212     9.994046    5.356586  53.533969
# 24           198    10.062365    5.288267  53.212474
# 23           188    10.114190    5.247024  53.069399
# 22           184    10.135696    5.214936  52.857006
# 21           155    10.307207    5.043425  51.983627
# 20           137    10.430651    4.983607  51.982263
# 18            68    11.131124    4.234107  47.130366
# 17            62    11.223498    4.127134  46.320884
# 16            52    11.399388    3.970292  45.258900
# 15            52    11.399388    3.951244  45.041762
# 14            45    11.543970    3.806662  43.943996
# 13            38    11.713046    3.637586  42.607214
# 12            24    12.172578    3.178054  38.685109
# 11            19    12.406193    2.944439  36.529279
# 51        729176     1.850962   13.499699  24.987427
# 52       1587944     1.072682   14.278273  15.316040
# 53       1587944     1.072682   14.277952  15.315695
# 54       1587944     1.072682   14.277952  15.315695
# 55       1587944     1.072682   14.277952  15.315695
# 56       1587944     1.072682   14.277952  15.315695
# 57       1588593     1.072273   14.278386  15.310326
# 58       1855262     0.917096   14.433553  13.236949
# 59       1855262     0.917096   14.433537  13.236935
# 60       4995959    -0.073508   15.424158  -1.133795

# %% [markdown]
# Although some properties are repeated, because of the nature of DBpedia, we see that features like `birthPlace, Queens` and `almaMater New_York_University` are more representative of the entities similar to `dbr:Martin_Scorsese`. Let us now pick the top 2 features to create reformulate the original query as :
# ```
# Select Distinct movie where {
# ?movie dbo:director ?e
# ?e http://dbpedia.org/ontology/birthPlace http://dbpedia.org/resource/Queens	 .
# ?e http://dbpedia.org/property/almaMater  http://dbpedia.org/resource/New_York_University .
# }
# ```
#
# Now running it to see the results we get :

# %%
# %%time 
dbpedia_query ="""
PREFIX  schema: <http://schema.org/>
PREFIX  dbr:  <http://dbpedia.org/resource/>
PREFIX  umbel-rc: <http://umbel.org/umbel/rc/>
PREFIX  dbc:  <http://dbpedia.org/resource/Category:>
PREFIX  owl:  <http://www.w3.org/2002/07/owl#>
PREFIX  yago: <http://dbpedia.org/class/yago/>
PREFIX  rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX  dbo:  <http://dbpedia.org/ontology/>
PREFIX  dbp:  <http://dbpedia.org/property/>
PREFIX  rdf:  <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX  dcterms: <http://purl.org/dc/terms/>
PREFIX  dbpedia-wikidata: <http://wikidata.dbpedia.org/resource/>
PREFIX  dul:  <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
PREFIX  foaf: <http://xmlns.com/foaf/0.1/>
PREFIX  dc:   <http://purl.org/dc/elements/1.1/>
PREFIX prov: <http://www.w3.org/ns/prov#>

Select Distinct ?movie ?e where {
# ?movie dbo:director ?e .
# ?e <http://dbpedia.org/ontology/birthPlace> <http://dbpedia.org/resource/New_York>     .    
# ?e <http://dbpedia.org/property/almaMater>  <http://dbpedia.org/resource/New_York_University> .
}
"""
dbpedia_endpoint = "http://zen.cs.rpi.edu:8890/sparql"
movies_df = execute_query(dbpedia_query,dbpedia_endpoint)
print("The toal movies directed by anybody are : " + str(movies_df.shape[0]))
display(movies_df)
# Out:
# The toal movies directed by anybody are : 53
#    e.type                                         e.value movie.type  \
# 0     uri      http://dbpedia.org/resource/Burt_Lancaster        uri
# 1     uri      http://dbpedia.org/resource/Burt_Lancaster        uri
# 2     uri     http://dbpedia.org/resource/Martin_Scorsese        uri
# 3     uri     http://dbpedia.org/resource/Martin_Scorsese        uri
# 4     uri     http://dbpedia.org/resource/Martin_Scorsese        uri
# 5     uri     http://dbpedia.org/resource/Martin_Scorsese        uri
# 6     uri     http://dbpedia.org/resource/Martin_Scorsese        uri
# 7     uri     http://dbpedia.org/resource/Martin_Scorsese        uri
# 8     uri     http://dbpedia.org/resource/Martin_Scorsese        uri
# 9     uri     http://dbpedia.org/resource/Martin_Scorsese        uri
# 10    uri     http://dbpedia.org/resource/Martin_Scorsese        uri
# 11    uri     http://dbpedia.org/resource/Martin_Scorsese        uri
# 12    uri     http://dbpedia.org/resource/Martin_Scorsese        uri
# 13    uri     http://dbpedia.org/resource/Martin_Scorsese        uri
# 14    uri     http://dbpedia.org/resource/Martin_Scorsese        uri
# 15    uri     http://dbpedia.org/resource/Martin_Scorsese        uri
# 16    uri     http://dbpedia.org/resource/Martin_Scorsese        uri
# 17    uri     http://dbpedia.org/resource/Martin_Scorsese        uri
# 18    uri     http://dbpedia.org/resource/Martin_Scorsese        uri
# 19    uri     http://dbpedia.org/resource/Martin_Scorsese        uri
# 20    uri     http://dbpedia.org/resource/Martin_Scorsese        uri
# 21    uri     http://dbpedia.org/resource/Martin_Scorsese        uri
# 22    uri     http://dbpedia.org/resource/Martin_Scorsese        uri
# 23    uri     http://dbpedia.org/resource/Martin_Scorsese        uri
# 24    uri     http://dbpedia.org/resource/Martin_Scorsese        uri
# 25    uri     http://dbpedia.org/resource/Martin_Scorsese        uri
# 26    uri     http://dbpedia.org/resource/Martin_Scorsese        uri
# 27    uri     http://dbpedia.org/resource/Martin_Scorsese        uri
# 28    uri     http://dbpedia.org/resource/Martin_Scorsese        uri
# 29    uri     http://dbpedia.org/resource/Martin_Scorsese        uri
# 30    uri     http://dbpedia.org/resource/Martin_Scorsese        uri
# 31    uri     http://dbpedia.org/resource/Martin_Scorsese        uri
# 32    uri     http://dbpedia.org/resource/Martin_Scorsese        uri
# 33    uri     http://dbpedia.org/resource/Martin_Scorsese        uri
# 34    uri     http://dbpedia.org/resource/Martin_Scorsese        uri
# 35    uri     http://dbpedia.org/resource/Martin_Scorsese        uri
# 36    uri     http://dbpedia.org/resource/Martin_Scorsese        uri
# 37    uri     http://dbpedia.org/resource/Martin_Scorsese        uri
# 38    uri     http://dbpedia.org/resource/Martin_Scorsese        uri
# 39    uri     http://dbpedia.org/resource/Martin_Scorsese        uri
# 40    uri     http://dbpedia.org/resource/Martin_Scorsese        uri
# 41    uri     http://dbpedia.org/resource/Martin_Scorsese        uri
# 42    uri     http://dbpedia.org/resource/Martin_Scorsese        uri
# 43    uri     http://dbpedia.org/resource/Martin_Scorsese        uri
# 44    uri     http://dbpedia.org/resource/Martin_Scorsese        uri
# 45    uri     http://dbpedia.org/resource/Martin_Scorsese        uri
# 46    uri     http://dbpedia.org/resource/Martin_Scorsese        uri
# 47    uri      http://dbpedia.org/resource/Andrew_Levitas        uri
# 48    uri  http://dbpedia.org/resource/Herbert_B._Leonard        uri
# 49    uri  http://dbpedia.org/resource/Herbert_B._Leonard        uri
# 50    uri         http://dbpedia.org/resource/Jesse_Dylan        uri
# 51    uri         http://dbpedia.org/resource/Jesse_Dylan        uri
# 52    uri         http://dbpedia.org/resource/Jesse_Dylan        uri
#
#                                                                                     movie.value
# 0                                                    http://dbpedia.org/resource/The_Kentuckian
# 1                                      http://dbpedia.org/resource/The_Midnight_Man_(1974_film)
# 2                                                     http://dbpedia.org/resource/Made_in_Milan
# 3                                                http://dbpedia.org/resource/The_Key_to_Reserva
# 4                                                      http://dbpedia.org/resource/Mean_Streets
# 5                                                       http://dbpedia.org/resource/Raging_Bull
# 6                                                       http://dbpedia.org/resource/Taxi_Driver
# 7                                   http://dbpedia.org/resource/Alice_Doesn't_Live_Here_Anymore
# 8                                    http://dbpedia.org/resource/The_King_of_Comedy_(1983_film)
# 9                                                     http://dbpedia.org/resource/Boxcar_Bertha
# 10                                   http://dbpedia.org/resource/Who's_That_Knocking_at_My_Door
# 11                                               http://dbpedia.org/resource/My_Voyage_to_Italy
# 12                                                       http://dbpedia.org/resource/Goodfellas
# 13                                               http://dbpedia.org/resource/After_Hours_(film)
# 14                                                 http://dbpedia.org/resource/New_York_Stories
# 15                                                           http://dbpedia.org/resource/Kundun
# 16                                                http://dbpedia.org/resource/No_Direction_Home
# 17                                                    http://dbpedia.org/resource/Street_Scenes
# 18                                                 http://dbpedia.org/resource/The_Blues_(film)
# 19                             http://dbpedia.org/resource/The_Last_Temptation_of_Christ_(film)
# 20                                                http://dbpedia.org/resource/Vinyl_(TV_series)
# 21                                            http://dbpedia.org/resource/Bringing_Out_the_Dead
# 22                                          http://dbpedia.org/resource/The_Aviator_(2004_film)
# 23                                            http://dbpedia.org/resource/Shutter_Island_(film)
# 24                                              http://dbpedia.org/resource/Silence_(2016_film)
# 25                                                    http://dbpedia.org/resource/Casino_(film)
# 26                                        http://dbpedia.org/resource/New_York,_New_York_(film)
# 27                                                     http://dbpedia.org/resource/The_Departed
# 28  http://dbpedia.org/resource/A_Personal_Journey_with_Martin_Scorsese_Through_American_Movies
# 29                                 http://dbpedia.org/resource/The_Age_of_Innocence_(1993_film)
# 30        http://dbpedia.org/resource/What's_a_Nice_Girl_Like_You_Doing_in_a_Place_Like_This%3F
# 31                                             http://dbpedia.org/resource/Shine_a_Light_(film)
# 32                         http://dbpedia.org/resource/Shine_a_Light_(The_Rolling_Stones_album)
# 33                    http://dbpedia.org/resource/George_Harrison:_Living_in_the_Material_World
# 34                                                 http://dbpedia.org/resource/A_Letter_to_Elia
# 35                                            http://dbpedia.org/resource/Cape_Fear_(1991_film)
# 36                                                http://dbpedia.org/resource/Gangs_of_New_York
# 37                                               http://dbpedia.org/resource/The_Color_of_Money
# 38                                                   http://dbpedia.org/resource/The_Last_Waltz
# 39                                                    http://dbpedia.org/resource/The_Big_Shave
# 40                                                  http://dbpedia.org/resource/Italianamerican
# 41                         http://dbpedia.org/resource/American_Boy:_A_Profile_of_Steven_Prince
# 42                                       http://dbpedia.org/resource/It's_Not_Just_You,_Murray!
# 43                                                      http://dbpedia.org/resource/Hugo_(film)
# 44                                       http://dbpedia.org/resource/Boardwalk_Empire_(episode)
# 45                              http://dbpedia.org/resource/The_Wolf_of_Wall_Street_(2013_film)
# 46                                           http://dbpedia.org/resource/Public_Speaking_(film)
# 47                                              http://dbpedia.org/resource/Lullaby_(2014_film)
# 48                                           http://dbpedia.org/resource/Going_Home_(1971_film)
# 49                                http://dbpedia.org/resource/The_Perils_of_Pauline_(1967_film)
# 50                                                 http://dbpedia.org/resource/American_Wedding
# 51                                                         http://dbpedia.org/resource/How_High
# 52                                  http://dbpedia.org/resource/Kicking_&_Screaming_(2005_film)
# CPU times: user 48 ms, sys: 4 ms, total: 52 ms
# Wall time: 53.4 ms

# %% [markdown]
# Now in the above result you see 53 movies which other people have also directed. Thus, you  have other entities like `dbr:Herbert_B.Leonard` and `dbr:Jesse_Dylan` and `dbr:Burt_Lancaster`, who are both directors from `New_York` and are also _film producers_.
#
# Let us also try another query using the other ranked properties i.e.
#
# ```
# Select Distinct ?movie ?e where {
# ?movie dbo:director ?e .
# ?e <http://purl.org/dc/terms/subject> <http://dbpedia.org/resource/Category:American_Roman_Catholics> .
# ?e <http://purl.org/dc/terms/subject> <http://dbpedia.org/resource/Category:New_York_Democrats> .
# }
# ```
#
# **Note** : We have already used the `birthPlace` and `almaMater`. So we use the other properties to explicitly be diverse in results.

# %%
# %%time 
dbpedia_query ="""
PREFIX  schema: <http://schema.org/>
PREFIX  dbr:  <http://dbpedia.org/resource/>
PREFIX  umbel-rc: <http://umbel.org/umbel/rc/>
PREFIX  dbc:  <http://dbpedia.org/resource/Category:>
PREFIX  owl:  <http://www.w3.org/2002/07/owl#>
PREFIX  yago: <http://dbpedia.org/class/yago/>
PREFIX  rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX  dbo:  <http://dbpedia.org/ontology/>
PREFIX  dbp:  <http://dbpedia.org/property/>
PREFIX  rdf:  <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX  dcterms: <http://purl.org/dc/terms/>
PREFIX  dbpedia-wikidata: <http://wikidata.dbpedia.org/resource/>
PREFIX  dul:  <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
PREFIX  foaf: <http://xmlns.com/foaf/0.1/>
PREFIX  dc:   <http://purl.org/dc/elements/1.1/>
PREFIX prov: <http://www.w3.org/ns/prov#>

Select Distinct ?movie ?e where {
# ?movie dbo:director ?e .
# ?e <http://purl.org/dc/terms/subject> <http://dbpedia.org/resource/Category:American_Roman_Catholics> .
# ?e <http://purl.org/dc/terms/subject> <http://dbpedia.org/resource/Category:New_York_Democrats> .
}
"""
dbpedia_endpoint = "http://zen.cs.rpi.edu:8890/sparql"
movies_df = execute_query(dbpedia_query,dbpedia_endpoint)
print("The toal movies directed by anybody are : " + str(movies_df.shape[0]))
display(movies_df)
# Out:
# The toal movies directed by anybody are : 49
#    e.type                                      e.value movie.type  \
# 0     uri     http://dbpedia.org/resource/James_Cagney        uri
# 1     uri  http://dbpedia.org/resource/Martin_Scorsese        uri
# 2     uri  http://dbpedia.org/resource/Martin_Scorsese        uri
# 3     uri  http://dbpedia.org/resource/Martin_Scorsese        uri
# 4     uri  http://dbpedia.org/resource/Martin_Scorsese        uri
# 5     uri  http://dbpedia.org/resource/Martin_Scorsese        uri
# 6     uri  http://dbpedia.org/resource/Martin_Scorsese        uri
# 7     uri  http://dbpedia.org/resource/Martin_Scorsese        uri
# 8     uri  http://dbpedia.org/resource/Martin_Scorsese        uri
# 9     uri  http://dbpedia.org/resource/Martin_Scorsese        uri
# 10    uri  http://dbpedia.org/resource/Martin_Scorsese        uri
# 11    uri  http://dbpedia.org/resource/Martin_Scorsese        uri
# 12    uri  http://dbpedia.org/resource/Martin_Scorsese        uri
# 13    uri  http://dbpedia.org/resource/Martin_Scorsese        uri
# 14    uri  http://dbpedia.org/resource/Martin_Scorsese        uri
# 15    uri  http://dbpedia.org/resource/Martin_Scorsese        uri
# 16    uri  http://dbpedia.org/resource/Martin_Scorsese        uri
# 17    uri  http://dbpedia.org/resource/Martin_Scorsese        uri
# 18    uri  http://dbpedia.org/resource/Martin_Scorsese        uri
# 19    uri  http://dbpedia.org/resource/Martin_Scorsese        uri
# 20    uri  http://dbpedia.org/resource/Martin_Scorsese        uri
# 21    uri  http://dbpedia.org/resource/Martin_Scorsese        uri
# 22    uri  http://dbpedia.org/resource/Martin_Scorsese        uri
# 23    uri  http://dbpedia.org/resource/Martin_Scorsese        uri
# 24    uri  http://dbpedia.org/resource/Martin_Scorsese        uri
# 25    uri  http://dbpedia.org/resource/Martin_Scorsese        uri
# 26    uri  http://dbpedia.org/resource/Martin_Scorsese        uri
# 27    uri  http://dbpedia.org/resource/Martin_Scorsese        uri
# 28    uri  http://dbpedia.org/resource/Martin_Scorsese        uri
# 29    uri  http://dbpedia.org/resource/Martin_Scorsese        uri
# 30    uri  http://dbpedia.org/resource/Martin_Scorsese        uri
# 31    uri  http://dbpedia.org/resource/Martin_Scorsese        uri
# 32    uri  http://dbpedia.org/resource/Martin_Scorsese        uri
# 33    uri  http://dbpedia.org/resource/Martin_Scorsese        uri
# 34    uri  http://dbpedia.org/resource/Martin_Scorsese        uri
# 35    uri  http://dbpedia.org/resource/Martin_Scorsese        uri
# 36    uri  http://dbpedia.org/resource/Martin_Scorsese        uri
# 37    uri  http://dbpedia.org/resource/Martin_Scorsese        uri
# 38    uri  http://dbpedia.org/resource/Martin_Scorsese        uri
# 39    uri  http://dbpedia.org/resource/Martin_Scorsese        uri
# 40    uri  http://dbpedia.org/resource/Martin_Scorsese        uri
# 41    uri  http://dbpedia.org/resource/Martin_Scorsese        uri
# 42    uri  http://dbpedia.org/resource/Martin_Scorsese        uri
# 43    uri  http://dbpedia.org/resource/Martin_Scorsese        uri
# 44    uri  http://dbpedia.org/resource/Martin_Scorsese        uri
# 45    uri  http://dbpedia.org/resource/Martin_Scorsese        uri
# 46    uri   http://dbpedia.org/resource/Robert_De_Niro        uri
# 47    uri   http://dbpedia.org/resource/Robert_De_Niro        uri
# 48    uri     http://dbpedia.org/resource/Alec_Baldwin        uri
#
#                                                                                     movie.value
# 0                                                 http://dbpedia.org/resource/Short_Cut_to_Hell
# 1                                                     http://dbpedia.org/resource/Made_in_Milan
# 2                                                http://dbpedia.org/resource/The_Key_to_Reserva
# 3                                                      http://dbpedia.org/resource/Mean_Streets
# 4                                                       http://dbpedia.org/resource/Raging_Bull
# 5                                                       http://dbpedia.org/resource/Taxi_Driver
# 6                                   http://dbpedia.org/resource/Alice_Doesn't_Live_Here_Anymore
# 7                                    http://dbpedia.org/resource/The_King_of_Comedy_(1983_film)
# 8                                                     http://dbpedia.org/resource/Boxcar_Bertha
# 9                                    http://dbpedia.org/resource/Who's_That_Knocking_at_My_Door
# 10                                               http://dbpedia.org/resource/My_Voyage_to_Italy
# 11                                                       http://dbpedia.org/resource/Goodfellas
# 12                                               http://dbpedia.org/resource/After_Hours_(film)
# 13                                                 http://dbpedia.org/resource/New_York_Stories
# 14                                                           http://dbpedia.org/resource/Kundun
# 15                                                http://dbpedia.org/resource/No_Direction_Home
# 16                                                    http://dbpedia.org/resource/Street_Scenes
# 17                                                 http://dbpedia.org/resource/The_Blues_(film)
# 18                             http://dbpedia.org/resource/The_Last_Temptation_of_Christ_(film)
# 19                                                http://dbpedia.org/resource/Vinyl_(TV_series)
# 20                                            http://dbpedia.org/resource/Bringing_Out_the_Dead
# 21                                          http://dbpedia.org/resource/The_Aviator_(2004_film)
# 22                                            http://dbpedia.org/resource/Shutter_Island_(film)
# 23                                              http://dbpedia.org/resource/Silence_(2016_film)
# 24                                                    http://dbpedia.org/resource/Casino_(film)
# 25                                        http://dbpedia.org/resource/New_York,_New_York_(film)
# 26                                                     http://dbpedia.org/resource/The_Departed
# 27  http://dbpedia.org/resource/A_Personal_Journey_with_Martin_Scorsese_Through_American_Movies
# 28                                 http://dbpedia.org/resource/The_Age_of_Innocence_(1993_film)
# 29        http://dbpedia.org/resource/What's_a_Nice_Girl_Like_You_Doing_in_a_Place_Like_This%3F
# 30                                             http://dbpedia.org/resource/Shine_a_Light_(film)
# 31                         http://dbpedia.org/resource/Shine_a_Light_(The_Rolling_Stones_album)
# 32                    http://dbpedia.org/resource/George_Harrison:_Living_in_the_Material_World
# 33                                                 http://dbpedia.org/resource/A_Letter_to_Elia
# 34                                            http://dbpedia.org/resource/Cape_Fear_(1991_film)
# 35                                                http://dbpedia.org/resource/Gangs_of_New_York
# 36                                               http://dbpedia.org/resource/The_Color_of_Money
# 37                                                   http://dbpedia.org/resource/The_Last_Waltz
# 38                                                    http://dbpedia.org/resource/The_Big_Shave
# 39                                                  http://dbpedia.org/resource/Italianamerican
# 40                         http://dbpedia.org/resource/American_Boy:_A_Profile_of_Steven_Prince
# 41                                       http://dbpedia.org/resource/It's_Not_Just_You,_Murray!
# 42                                                      http://dbpedia.org/resource/Hugo_(film)
# 43                                       http://dbpedia.org/resource/Boardwalk_Empire_(episode)
# 44                              http://dbpedia.org/resource/The_Wolf_of_Wall_Street_(2013_film)
# 45                                           http://dbpedia.org/resource/Public_Speaking_(film)
# 46                                         http://dbpedia.org/resource/The_Good_Shepherd_(film)
# 47                                                     http://dbpedia.org/resource/A_Bronx_Tale
# 48                                            http://dbpedia.org/resource/Shortcut_to_Happiness
# CPU times: user 28 ms, sys: 8 ms, total: 36 ms
# Wall time: 37 ms

# %% [markdown]
# Now in the above result you see 49 movies which other people have also directed. Thus, you  have other entities like `dbr:Robert_De_Niro` and `dbr:Alec_Baldwin`, who are related to `dbr:Martin_Scorsese`.
#
# So we now have the following comparisons between relaxation and reformulation. There are a total of `45 + 4 + 8 = 57 ` unique results out of the reformulation procedure, whereas the relaxation has a total of `102808` results. The `57` results are more related to the `?movie` variable of the original query because of using the _contextualized_ features.
#
# ### Results Comparison
# | Original Query        | **Relaxation**           | Ref-1 | Ref-2 | Combined |
# | ------------- |:-------------:|:--------:|:-------:|:---------|
# |45|102808|49|53|57|
#
# ### Time Comparison
#  | **Relaxation**           | Ref-1 | Ref-2 |
# |:-------------:|:--------:|:-------:|
# |5010ms|53.4ms|39ms|
#
# * Clearly the **relaxation results are higher, whereas the reformulation results are lesser**. This makes this kind of reformulation more precise.
# * In addition the time calculation shows that the **resulting reformulations also run in lesser time than the relaxed version of the query**.
#
# ![results](files/images/Scorsese_chart.png)
#
# You can access the [jsfiddle](http://jsfiddle.net/N00bsie/dynpyrLq/3/)

# %% [markdown]
# # Conclusions
#
# From the above results, we believe that this technique can be used to _contextualize_ entities and be used to reformulate entities in entity queries instead of relaxation.
